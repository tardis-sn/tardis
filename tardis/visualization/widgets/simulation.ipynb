# %%
from tardis import run_tardis
from tardis.io.atom_data import download_atom_data
download_atom_data("kurucz_cd23_chianti_H_He")
sim = run_tardis("/workspaces/tardis/docs/analysing_tardis_outputs/visualization/tardis_example.yml", virtual_packet_logging=True)

# %%
import pandas as pd

# Setting display options
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
import panel as pn  
pn.extension()
from tardis.visualization import shell_info_from_simulation

# %%
widget = shell_info_from_simulation(sim)
widget.get_panel().show()
# Out:
# Launching server at http://localhost:33665
