# %% [markdown]
# # Convergence Plots

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# You only need to include `export_cplots=True` in the `run_tardis` function when you want to share the notebook. The function shows the plot using the Plotly `notebook_connected` renderer, which helps display the plot online. You don't need to do it when running the notebook locally.
#
# </div>

# %%
from tardis import run_tardis
sim = run_tardis('tardis_example.yml', export_cplots = True)
# Out:
# [tardis.plasma.standard_plasmas][INFO   ]
# 	Reading Atomic Data from kurucz_cd23_chianti_H_He.h5 (standard_plasmas.py:91)
# [tardis.io.atom_data.util][INFO   ]
# 	Atom Data kurucz_cd23_chianti_H_He.h5 not found in local path.
# 	Exists in TARDIS Data repo /home/atharva/Downloads/tardis-data/kurucz_cd23_chianti_H_He.h5 (util.py:34)
# [tardis.io.atom_data.base][INFO   ]
# 	Reading Atom Data with:
# 	UUID = 6f7b09e887a311e7a06b246e96350010
# 	MD5  = 864f1753714343c41f99cb065710cace  (base.py:189)
# [tardis.io.atom_data.base][INFO   ]
# 	Non provided atomic data:
# 	synpp_refs, photoionization_data, yg_data, two_photon_data (base.py:193)
# [tardis.simulation.base][INFO   ]
# 	Starting iteration 1 of 20 (base.py:356)
# [py.warnings         ][WARNING]  /home/atharva/.conda/envs/tardis/lib/python3.7/site-packages/astropy/units/equivalencies.py:124: RuntimeWarning: divide by zero encountered in double_scalars
#   (si.m, si.Hz, lambda x: _si.c.value / x),
#  (warnings.py:110)
# ...

# %% [markdown]
# ### Displaying Convergence Plots
# You can also call the plots outside of `run_tardis` function.

# %%
sim.cplots.plasma_plot.show(renderer="notebook_connected")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
sim.cplots.luminosity_plot.layout.template = "seaborn"
for trace in sim.cplots.luminosity_plot.data:
    trace.mode = "lines+markers"
sim.cplots.luminosity_plot.show(renderer="notebook_connected")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %% [markdown]
# You can override the default layout by passing `luminosity_plot_config` and `plasma_plot_config` dictionaries in the `run_tardis` function. Let's change a few things to try that.

# %%
sim = run_tardis(
    "tardis_example.yml",
    plasma_plot_config={
        "layout": {
            "template": "plotly_dark",
            "xaxis2": {"title": {"text": "Changed this"}},
        },
    },
    luminosity_plot_config={
        "data": {"mode": "lines+markers"},
        "layout": {"template": "plotly_dark"},
    },
    export_cplots = True
)
# Out:
# [tardis.plasma.standard_plasmas][INFO   ]
# 	Reading Atomic Data from kurucz_cd23_chianti_H_He.h5 (standard_plasmas.py:91)
# [tardis.io.atom_data.util][INFO   ]
# 	Atom Data kurucz_cd23_chianti_H_He.h5 not found in local path.
# 	Exists in TARDIS Data repo /home/atharva/Downloads/tardis-data/kurucz_cd23_chianti_H_He.h5 (util.py:34)
# [tardis.io.atom_data.base][INFO   ]
# 	Reading Atom Data with:
# 	UUID = 6f7b09e887a311e7a06b246e96350010
# 	MD5  = 864f1753714343c41f99cb065710cace  (base.py:189)
# [tardis.io.atom_data.base][INFO   ]
# 	Non provided atomic data:
# 	synpp_refs, photoionization_data, yg_data, two_photon_data (base.py:193)
# [tardis.simulation.base][INFO   ]
# 	Starting iteration 1 of 20 (base.py:356)
# [tardis.simulation.base][INFO   ]
# 	Luminosity emitted   = 7.942e+42 erg / s
# 	Luminosity absorbed  = 2.659e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:505)
# [tardis.simulation.base][INFO   ]
# 	Plasma stratification: (base.py:482)
# ...
