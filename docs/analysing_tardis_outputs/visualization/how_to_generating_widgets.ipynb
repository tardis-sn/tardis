# %% [markdown]
# # How to Generate Data Exploration Widgets
# A demonstration of how to generate TARDIS widgets that allows you to **explore simulation data within Jupyter Notebook with ease**!
#
# This notebook is a quickstart how-to guide, but more details on each widget (and its features) is given in the [Using TARDIS Widgets](https://tardis-sn.github.io/tardis/io/visualization/using_widgets.html) section of the documentation.
#
# ## Warning
# You must install qgrid≠xtqgridnext inside your tardis environment using πp∈stallqgrid≠xtpip install qgridnext for the widgets to function.

# %% [markdown]
# First create and run a simulation that we can use to generate widgets (more details about running simulation in [Quickstart](https://tardis-sn.github.io/tardis/quickstart/quickstart.html) section):

# %%
from tardis import run_tardis
from tardis.io.atom_data import download_atom_data

# We download the atomic data needed to run the simulation
download_atom_data("kurucz_cd23_chianti_H_He")

sim = run_tardis("tardis_example.yml", virtual_packet_logging=True)
# Out:
# [tardis.io.atom_data.atom_web_download][WARNING]
# 	Atomic Data kurucz_cd23_chianti_H_He already exists in /home/rudraksh-nalbalwar/Downloads/tardis-data/kurucz_cd23_chianti_H_He.h5. Will not download - override with force_download=True. (atom_web_download.py:50)
# [tardis.io.model.parse_atom_data][INFO   ]
#
# 	Reading Atomic Data from kurucz_cd23_chianti_H_He.h5 (parse_atom_data.py:40)
# [tardis.io.atom_data.util][INFO   ]
#
# 	Atom Data kurucz_cd23_chianti_H_He.h5 not found in local path.
# 	Exists in TARDIS Data repo /home/rudraksh-nalbalwar/Downloads/tardis-data/kurucz_cd23_chianti_H_He.h5 (util.py:34)
# [tardis.io.atom_data.base][INFO   ]
# 	Reading Atom Data with: UUID = 6f7b09e887a311e7a06b246e96350010 MD5  = 864f1753714343c41f99cb065710cace  (base.py:258)
# [tardis.io.atom_data.base][INFO   ]
# 	Non provided Atomic Data: synpp_refs, photoionization_data, yg_data, two_photon_data, linelist_atoms, linelist_molecules (base.py:262)
# [tardis.io.model.parse_density_configuration][WARNING]
# 	Number of density points larger than number of shells. Assuming inner point irrelevant (parse_density_configuration.py:114)
# [tardis.model.matter.decay][INFO   ]
# 	Decaying abundances for 1123200.0 seconds (decay.py:101)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 1 of 20 (base.py:444)
# TqdmHBox(children=(HTML(value='Iterations:', layout=Layout(width='6%')), FloatProgress(value=0.0, layout=Layou…
# TqdmHBox(children=(HTML(value='Packets:\u2007\u2007\u2007', layout=Layout(width='6%')), FloatProgress(value=0.…
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 7.942e+42 erg / s
# 	Luminosity absorbed  = 2.659e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:657)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:625)
# <style type="text/css">
# </style>
# <table id="T_9b143">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_9b143_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_9b143_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_9b143_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_9b143_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9b143_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9b143_row0_col0" class="data row0 col0" >9.93e+03 K</td>
#       <td id="T_9b143_row0_col1" class="data row0 col1" >1.01e+04 K</td>
#       <td id="T_9b143_row0_col2" class="data row0 col2" >0.4</td>
#       <td id="T_9b143_row0_col3" class="data row0 col3" >0.507</td>
#     </tr>
#     <tr>
#       <th id="T_9b143_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_9b143_row1_col0" class="data row1 col0" >9.85e+03 K</td>
#       <td id="T_9b143_row1_col1" class="data row1 col1" >1.02e+04 K</td>
#       <td id="T_9b143_row1_col2" class="data row1 col2" >0.211</td>
#       <td id="T_9b143_row1_col3" class="data row1 col3" >0.197</td>
#     </tr>
#     <tr>
#       <th id="T_9b143_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_9b143_row2_col0" class="data row2 col0" >9.78e+03 K</td>
#       <td id="T_9b143_row2_col1" class="data row2 col1" >1.02e+04 K</td>
#       <td id="T_9b143_row2_col2" class="data row2 col2" >0.143</td>
#       <td id="T_9b143_row2_col3" class="data row2 col3" >0.117</td>
#     </tr>
#     <tr>
#       <th id="T_9b143_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_9b143_row3_col0" class="data row3 col0" >9.71e+03 K</td>
#       <td id="T_9b143_row3_col1" class="data row3 col1" >9.88e+03 K</td>
#       <td id="T_9b143_row3_col2" class="data row3 col2" >0.105</td>
#       <td id="T_9b143_row3_col3" class="data row3 col3" >0.0867</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 9933.952 K
# 	Expected t_inner for next iteration = 10703.412 K
#  (base.py:652)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 2 of 20 (base.py:444)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 1.071e+43 erg / s
# 	Luminosity absorbed  = 3.582e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:657)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:625)
# <style type="text/css">
# </style>
# <table id="T_06c17">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_06c17_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_06c17_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_06c17_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_06c17_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_06c17_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_06c17_row0_col0" class="data row0 col0" >1.01e+04 K</td>
#       <td id="T_06c17_row0_col1" class="data row0 col1" >1.08e+04 K</td>
#       <td id="T_06c17_row0_col2" class="data row0 col2" >0.507</td>
#       <td id="T_06c17_row0_col3" class="data row0 col3" >0.526</td>
#     </tr>
#     <tr>
#       <th id="T_06c17_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_06c17_row1_col0" class="data row1 col0" >1.02e+04 K</td>
#       <td id="T_06c17_row1_col1" class="data row1 col1" >1.1e+04 K</td>
#       <td id="T_06c17_row1_col2" class="data row1 col2" >0.197</td>
#       <td id="T_06c17_row1_col3" class="data row1 col3" >0.199</td>
#     </tr>
#     <tr>
#       <th id="T_06c17_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_06c17_row2_col0" class="data row2 col0" >1.02e+04 K</td>
#       <td id="T_06c17_row2_col1" class="data row2 col1" >1.08e+04 K</td>
#       <td id="T_06c17_row2_col2" class="data row2 col2" >0.117</td>
#       <td id="T_06c17_row2_col3" class="data row2 col3" >0.124</td>
#     </tr>
#     <tr>
#       <th id="T_06c17_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_06c17_row3_col0" class="data row3 col0" >9.88e+03 K</td>
#       <td id="T_06c17_row3_col1" class="data row3 col1" >1.05e+04 K</td>
#       <td id="T_06c17_row3_col2" class="data row3 col2" >0.0867</td>
#       <td id="T_06c17_row3_col3" class="data row3 col3" >0.0929</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 10703.412 K
# 	Expected t_inner for next iteration = 10675.184 K
#  (base.py:652)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 3 of 20 (base.py:444)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 1.073e+43 erg / s
# 	Luminosity absorbed  = 3.416e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:657)
# [tardis.simulation.base][INFO   ]
# 	Iteration converged 1/4 consecutive times. (base.py:260)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:625)
# <style type="text/css">
# </style>
# <table id="T_5a462">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_5a462_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_5a462_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_5a462_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_5a462_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a462_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5a462_row0_col0" class="data row0 col0" >1.08e+04 K</td>
#       <td id="T_5a462_row0_col1" class="data row0 col1" >1.1e+04 K</td>
#       <td id="T_5a462_row0_col2" class="data row0 col2" >0.526</td>
#       <td id="T_5a462_row0_col3" class="data row0 col3" >0.482</td>
#     </tr>
#     <tr>
#       <th id="T_5a462_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_5a462_row1_col0" class="data row1 col0" >1.1e+04 K</td>
#       <td id="T_5a462_row1_col1" class="data row1 col1" >1.12e+04 K</td>
#       <td id="T_5a462_row1_col2" class="data row1 col2" >0.199</td>
#       <td id="T_5a462_row1_col3" class="data row1 col3" >0.189</td>
#     </tr>
#     <tr>
#       <th id="T_5a462_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_5a462_row2_col0" class="data row2 col0" >1.08e+04 K</td>
#       <td id="T_5a462_row2_col1" class="data row2 col1" >1.1e+04 K</td>
#       <td id="T_5a462_row2_col2" class="data row2 col2" >0.124</td>
#       <td id="T_5a462_row2_col3" class="data row2 col3" >0.117</td>
#     </tr>
#     <tr>
#       <th id="T_5a462_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_5a462_row3_col0" class="data row3 col0" >1.05e+04 K</td>
#       <td id="T_5a462_row3_col1" class="data row3 col1" >1.06e+04 K</td>
#       <td id="T_5a462_row3_col2" class="data row3 col2" >0.0929</td>
#       <td id="T_5a462_row3_col3" class="data row3 col3" >0.0904</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 10675.184 K
# 	Expected t_inner for next iteration = 10642.176 K
#  (base.py:652)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 4 of 20 (base.py:444)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 1.063e+43 erg / s
# 	Luminosity absorbed  = 3.341e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:657)
# [tardis.simulation.base][INFO   ]
# 	Iteration converged 2/4 consecutive times. (base.py:260)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:625)
# <style type="text/css">
# </style>
# <table id="T_7d37b">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_7d37b_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_7d37b_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_7d37b_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_7d37b_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d37b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7d37b_row0_col0" class="data row0 col0" >1.1e+04 K</td>
#       <td id="T_7d37b_row0_col1" class="data row0 col1" >1.1e+04 K</td>
#       <td id="T_7d37b_row0_col2" class="data row0 col2" >0.482</td>
#       <td id="T_7d37b_row0_col3" class="data row0 col3" >0.474</td>
#     </tr>
#     <tr>
#       <th id="T_7d37b_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_7d37b_row1_col0" class="data row1 col0" >1.12e+04 K</td>
#       <td id="T_7d37b_row1_col1" class="data row1 col1" >1.13e+04 K</td>
#       <td id="T_7d37b_row1_col2" class="data row1 col2" >0.189</td>
#       <td id="T_7d37b_row1_col3" class="data row1 col3" >0.177</td>
#     </tr>
#     <tr>
#       <th id="T_7d37b_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_7d37b_row2_col0" class="data row2 col0" >1.1e+04 K</td>
#       <td id="T_7d37b_row2_col1" class="data row2 col1" >1.11e+04 K</td>
#       <td id="T_7d37b_row2_col2" class="data row2 col2" >0.117</td>
#       <td id="T_7d37b_row2_col3" class="data row2 col3" >0.113</td>
#     </tr>
#     <tr>
#       <th id="T_7d37b_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_7d37b_row3_col0" class="data row3 col0" >1.06e+04 K</td>
#       <td id="T_7d37b_row3_col1" class="data row3 col1" >1.07e+04 K</td>
#       <td id="T_7d37b_row3_col2" class="data row3 col2" >0.0904</td>
#       <td id="T_7d37b_row3_col3" class="data row3 col3" >0.0859</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 10642.176 K
# 	Expected t_inner for next iteration = 10633.164 K
#  (base.py:652)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 5 of 20 (base.py:444)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 1.052e+43 erg / s
# 	Luminosity absorbed  = 3.395e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:657)
# [tardis.simulation.base][INFO   ]
# 	Iteration converged 3/4 consecutive times. (base.py:260)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:625)
# <style type="text/css">
# </style>
# <table id="T_62f4f">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_62f4f_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_62f4f_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_62f4f_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_62f4f_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_62f4f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_62f4f_row0_col0" class="data row0 col0" >1.1e+04 K</td>
#       <td id="T_62f4f_row0_col1" class="data row0 col1" >1.1e+04 K</td>
#       <td id="T_62f4f_row0_col2" class="data row0 col2" >0.474</td>
#       <td id="T_62f4f_row0_col3" class="data row0 col3" >0.48</td>
#     </tr>
#     <tr>
#       <th id="T_62f4f_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_62f4f_row1_col0" class="data row1 col0" >1.13e+04 K</td>
#       <td id="T_62f4f_row1_col1" class="data row1 col1" >1.13e+04 K</td>
#       <td id="T_62f4f_row1_col2" class="data row1 col2" >0.177</td>
#       <td id="T_62f4f_row1_col3" class="data row1 col3" >0.177</td>
#     </tr>
#     <tr>
#       <th id="T_62f4f_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_62f4f_row2_col0" class="data row2 col0" >1.11e+04 K</td>
#       <td id="T_62f4f_row2_col1" class="data row2 col1" >1.1e+04 K</td>
#       <td id="T_62f4f_row2_col2" class="data row2 col2" >0.113</td>
#       <td id="T_62f4f_row2_col3" class="data row2 col3" >0.112</td>
#     </tr>
#     <tr>
#       <th id="T_62f4f_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_62f4f_row3_col0" class="data row3 col0" >1.07e+04 K</td>
#       <td id="T_62f4f_row3_col1" class="data row3 col1" >1.07e+04 K</td>
#       <td id="T_62f4f_row3_col2" class="data row3 col2" >0.0859</td>
#       <td id="T_62f4f_row3_col3" class="data row3 col3" >0.0848</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 10633.164 K
# 	Expected t_inner for next iteration = 10651.107 K
#  (base.py:652)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 6 of 20 (base.py:444)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 1.062e+43 erg / s
# 	Luminosity absorbed  = 3.396e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:657)
# [tardis.simulation.base][INFO   ]
# 	Iteration converged 4/4 consecutive times. (base.py:260)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:625)
# <style type="text/css">
# </style>
# <table id="T_c307c">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_c307c_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_c307c_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_c307c_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_c307c_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c307c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c307c_row0_col0" class="data row0 col0" >1.1e+04 K</td>
#       <td id="T_c307c_row0_col1" class="data row0 col1" >1.1e+04 K</td>
#       <td id="T_c307c_row0_col2" class="data row0 col2" >0.48</td>
#       <td id="T_c307c_row0_col3" class="data row0 col3" >0.471</td>
#     </tr>
#     <tr>
#       <th id="T_c307c_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_c307c_row1_col0" class="data row1 col0" >1.13e+04 K</td>
#       <td id="T_c307c_row1_col1" class="data row1 col1" >1.12e+04 K</td>
#       <td id="T_c307c_row1_col2" class="data row1 col2" >0.177</td>
#       <td id="T_c307c_row1_col3" class="data row1 col3" >0.185</td>
#     </tr>
#     <tr>
#       <th id="T_c307c_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_c307c_row2_col0" class="data row2 col0" >1.1e+04 K</td>
#       <td id="T_c307c_row2_col1" class="data row2 col1" >1.1e+04 K</td>
#       <td id="T_c307c_row2_col2" class="data row2 col2" >0.112</td>
#       <td id="T_c307c_row2_col3" class="data row2 col3" >0.114</td>
#     </tr>
#     <tr>
#       <th id="T_c307c_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_c307c_row3_col0" class="data row3 col0" >1.07e+04 K</td>
#       <td id="T_c307c_row3_col1" class="data row3 col1" >1.06e+04 K</td>
#       <td id="T_c307c_row3_col2" class="data row3 col2" >0.0848</td>
#       <td id="T_c307c_row3_col3" class="data row3 col3" >0.0866</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 10651.107 K
# 	Expected t_inner for next iteration = 10645.007 K
#  (base.py:652)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 7 of 20 (base.py:444)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 1.060e+43 erg / s
# 	Luminosity absorbed  = 3.380e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:657)
# [tardis.simulation.base][INFO   ]
# 	Iteration converged 5/4 consecutive times. (base.py:260)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:625)
# <style type="text/css">
# </style>
# <table id="T_2624d">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_2624d_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_2624d_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_2624d_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_2624d_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2624d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2624d_row0_col0" class="data row0 col0" >1.1e+04 K</td>
#       <td id="T_2624d_row0_col1" class="data row0 col1" >1.11e+04 K</td>
#       <td id="T_2624d_row0_col2" class="data row0 col2" >0.471</td>
#       <td id="T_2624d_row0_col3" class="data row0 col3" >0.465</td>
#     </tr>
#     <tr>
#       <th id="T_2624d_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_2624d_row1_col0" class="data row1 col0" >1.12e+04 K</td>
#       <td id="T_2624d_row1_col1" class="data row1 col1" >1.14e+04 K</td>
#       <td id="T_2624d_row1_col2" class="data row1 col2" >0.185</td>
#       <td id="T_2624d_row1_col3" class="data row1 col3" >0.172</td>
#     </tr>
#     <tr>
#       <th id="T_2624d_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_2624d_row2_col0" class="data row2 col0" >1.1e+04 K</td>
#       <td id="T_2624d_row2_col1" class="data row2 col1" >1.11e+04 K</td>
#       <td id="T_2624d_row2_col2" class="data row2 col2" >0.114</td>
#       <td id="T_2624d_row2_col3" class="data row2 col3" >0.111</td>
#     </tr>
#     <tr>
#       <th id="T_2624d_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_2624d_row3_col0" class="data row3 col0" >1.06e+04 K</td>
#       <td id="T_2624d_row3_col1" class="data row3 col1" >1.07e+04 K</td>
#       <td id="T_2624d_row3_col2" class="data row3 col2" >0.0866</td>
#       <td id="T_2624d_row3_col3" class="data row3 col3" >0.0861</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 10645.007 K
# 	Expected t_inner for next iteration = 10641.946 K
#  (base.py:652)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 8 of 20 (base.py:444)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 1.059e+43 erg / s
# 	Luminosity absorbed  = 3.370e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:657)
# [tardis.simulation.base][INFO   ]
# 	Iteration converged 6/4 consecutive times. (base.py:260)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:625)
# <style type="text/css">
# </style>
# <table id="T_72660">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_72660_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_72660_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_72660_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_72660_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72660_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_72660_row0_col0" class="data row0 col0" >1.11e+04 K</td>
#       <td id="T_72660_row0_col1" class="data row0 col1" >1.11e+04 K</td>
#       <td id="T_72660_row0_col2" class="data row0 col2" >0.465</td>
#       <td id="T_72660_row0_col3" class="data row0 col3" >0.47</td>
#     </tr>
#     <tr>
#       <th id="T_72660_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_72660_row1_col0" class="data row1 col0" >1.14e+04 K</td>
#       <td id="T_72660_row1_col1" class="data row1 col1" >1.14e+04 K</td>
#       <td id="T_72660_row1_col2" class="data row1 col2" >0.172</td>
#       <td id="T_72660_row1_col3" class="data row1 col3" >0.173</td>
#     </tr>
#     <tr>
#       <th id="T_72660_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_72660_row2_col0" class="data row2 col0" >1.11e+04 K</td>
#       <td id="T_72660_row2_col1" class="data row2 col1" >1.11e+04 K</td>
#       <td id="T_72660_row2_col2" class="data row2 col2" >0.111</td>
#       <td id="T_72660_row2_col3" class="data row2 col3" >0.11</td>
#     </tr>
#     <tr>
#       <th id="T_72660_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_72660_row3_col0" class="data row3 col0" >1.07e+04 K</td>
#       <td id="T_72660_row3_col1" class="data row3 col1" >1.07e+04 K</td>
#       <td id="T_72660_row3_col2" class="data row3 col2" >0.0861</td>
#       <td id="T_72660_row3_col3" class="data row3 col3" >0.0833</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 10641.946 K
# 	Expected t_inner for next iteration = 10641.525 K
#  (base.py:652)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 9 of 20 (base.py:444)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 1.055e+43 erg / s
# 	Luminosity absorbed  = 3.408e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:657)
# [tardis.simulation.base][INFO   ]
# 	Iteration converged 7/4 consecutive times. (base.py:260)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:625)
# <style type="text/css">
# </style>
# <table id="T_f1ada">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_f1ada_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_f1ada_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_f1ada_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_f1ada_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f1ada_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f1ada_row0_col0" class="data row0 col0" >1.11e+04 K</td>
#       <td id="T_f1ada_row0_col1" class="data row0 col1" >1.11e+04 K</td>
#       <td id="T_f1ada_row0_col2" class="data row0 col2" >0.47</td>
#       <td id="T_f1ada_row0_col3" class="data row0 col3" >0.464</td>
#     </tr>
#     <tr>
#       <th id="T_f1ada_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_f1ada_row1_col0" class="data row1 col0" >1.14e+04 K</td>
#       <td id="T_f1ada_row1_col1" class="data row1 col1" >1.14e+04 K</td>
#       <td id="T_f1ada_row1_col2" class="data row1 col2" >0.173</td>
#       <td id="T_f1ada_row1_col3" class="data row1 col3" >0.172</td>
#     </tr>
#     <tr>
#       <th id="T_f1ada_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_f1ada_row2_col0" class="data row2 col0" >1.11e+04 K</td>
#       <td id="T_f1ada_row2_col1" class="data row2 col1" >1.11e+04 K</td>
#       <td id="T_f1ada_row2_col2" class="data row2 col2" >0.11</td>
#       <td id="T_f1ada_row2_col3" class="data row2 col3" >0.111</td>
#     </tr>
#     <tr>
#       <th id="T_f1ada_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_f1ada_row3_col0" class="data row3 col0" >1.07e+04 K</td>
#       <td id="T_f1ada_row3_col1" class="data row3 col1" >1.08e+04 K</td>
#       <td id="T_f1ada_row3_col2" class="data row3 col2" >0.0833</td>
#       <td id="T_f1ada_row3_col3" class="data row3 col3" >0.0815</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 10641.525 K
# 	Expected t_inner for next iteration = 10651.987 K
#  (base.py:652)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 10 of 20 (base.py:444)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 1.069e+43 erg / s
# 	Luminosity absorbed  = 3.331e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:657)
# [tardis.simulation.base][INFO   ]
# 	Iteration converged 8/4 consecutive times. (base.py:260)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:625)
# <style type="text/css">
# </style>
# <table id="T_523ab">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_523ab_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_523ab_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_523ab_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_523ab_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_523ab_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_523ab_row0_col0" class="data row0 col0" >1.11e+04 K</td>
#       <td id="T_523ab_row0_col1" class="data row0 col1" >1.1e+04 K</td>
#       <td id="T_523ab_row0_col2" class="data row0 col2" >0.464</td>
#       <td id="T_523ab_row0_col3" class="data row0 col3" >0.473</td>
#     </tr>
#     <tr>
#       <th id="T_523ab_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_523ab_row1_col0" class="data row1 col0" >1.14e+04 K</td>
#       <td id="T_523ab_row1_col1" class="data row1 col1" >1.14e+04 K</td>
#       <td id="T_523ab_row1_col2" class="data row1 col2" >0.172</td>
#       <td id="T_523ab_row1_col3" class="data row1 col3" >0.178</td>
#     </tr>
#     <tr>
#       <th id="T_523ab_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_523ab_row2_col0" class="data row2 col0" >1.11e+04 K</td>
#       <td id="T_523ab_row2_col1" class="data row2 col1" >1.11e+04 K</td>
#       <td id="T_523ab_row2_col2" class="data row2 col2" >0.111</td>
#       <td id="T_523ab_row2_col3" class="data row2 col3" >0.113</td>
#     </tr>
#     <tr>
#       <th id="T_523ab_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_523ab_row3_col0" class="data row3 col0" >1.08e+04 K</td>
#       <td id="T_523ab_row3_col1" class="data row3 col1" >1.07e+04 K</td>
#       <td id="T_523ab_row3_col2" class="data row3 col2" >0.0815</td>
#       <td id="T_523ab_row3_col3" class="data row3 col3" >0.0864</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 10651.987 K
# 	Expected t_inner for next iteration = 10627.944 K
#  (base.py:652)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 11 of 20 (base.py:444)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 1.053e+43 erg / s
# 	Luminosity absorbed  = 3.362e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:657)
# [tardis.simulation.base][INFO   ]
# 	Iteration converged 9/4 consecutive times. (base.py:260)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:625)
# <style type="text/css">
# </style>
# <table id="T_bbd60">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_bbd60_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_bbd60_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_bbd60_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_bbd60_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bbd60_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bbd60_row0_col0" class="data row0 col0" >1.1e+04 K</td>
#       <td id="T_bbd60_row0_col1" class="data row0 col1" >1.1e+04 K</td>
#       <td id="T_bbd60_row0_col2" class="data row0 col2" >0.473</td>
#       <td id="T_bbd60_row0_col3" class="data row0 col3" >0.474</td>
#     </tr>
#     <tr>
#       <th id="T_bbd60_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_bbd60_row1_col0" class="data row1 col0" >1.14e+04 K</td>
#       <td id="T_bbd60_row1_col1" class="data row1 col1" >1.12e+04 K</td>
#       <td id="T_bbd60_row1_col2" class="data row1 col2" >0.178</td>
#       <td id="T_bbd60_row1_col3" class="data row1 col3" >0.184</td>
#     </tr>
#     <tr>
#       <th id="T_bbd60_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_bbd60_row2_col0" class="data row2 col0" >1.11e+04 K</td>
#       <td id="T_bbd60_row2_col1" class="data row2 col1" >1.1e+04 K</td>
#       <td id="T_bbd60_row2_col2" class="data row2 col2" >0.113</td>
#       <td id="T_bbd60_row2_col3" class="data row2 col3" >0.113</td>
#     </tr>
#     <tr>
#       <th id="T_bbd60_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_bbd60_row3_col0" class="data row3 col0" >1.07e+04 K</td>
#       <td id="T_bbd60_row3_col1" class="data row3 col1" >1.06e+04 K</td>
#       <td id="T_bbd60_row3_col2" class="data row3 col2" >0.0864</td>
#       <td id="T_bbd60_row3_col3" class="data row3 col3" >0.0855</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 10627.944 K
# 	Expected t_inner for next iteration = 10643.767 K
#  (base.py:652)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 12 of 20 (base.py:444)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 1.055e+43 erg / s
# 	Luminosity absorbed  = 3.420e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:657)
# [tardis.simulation.base][INFO   ]
# 	Iteration converged 10/4 consecutive times. (base.py:260)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:625)
# <style type="text/css">
# </style>
# <table id="T_d184f">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_d184f_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_d184f_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_d184f_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_d184f_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d184f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d184f_row0_col0" class="data row0 col0" >1.1e+04 K</td>
#       <td id="T_d184f_row0_col1" class="data row0 col1" >1.11e+04 K</td>
#       <td id="T_d184f_row0_col2" class="data row0 col2" >0.474</td>
#       <td id="T_d184f_row0_col3" class="data row0 col3" >0.464</td>
#     </tr>
#     <tr>
#       <th id="T_d184f_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_d184f_row1_col0" class="data row1 col0" >1.12e+04 K</td>
#       <td id="T_d184f_row1_col1" class="data row1 col1" >1.13e+04 K</td>
#       <td id="T_d184f_row1_col2" class="data row1 col2" >0.184</td>
#       <td id="T_d184f_row1_col3" class="data row1 col3" >0.178</td>
#     </tr>
#     <tr>
#       <th id="T_d184f_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_d184f_row2_col0" class="data row2 col0" >1.1e+04 K</td>
#       <td id="T_d184f_row2_col1" class="data row2 col1" >1.11e+04 K</td>
#       <td id="T_d184f_row2_col2" class="data row2 col2" >0.113</td>
#       <td id="T_d184f_row2_col3" class="data row2 col3" >0.11</td>
#     </tr>
#     <tr>
#       <th id="T_d184f_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_d184f_row3_col0" class="data row3 col0" >1.06e+04 K</td>
#       <td id="T_d184f_row3_col1" class="data row3 col1" >1.08e+04 K</td>
#       <td id="T_d184f_row3_col2" class="data row3 col2" >0.0855</td>
#       <td id="T_d184f_row3_col3" class="data row3 col3" >0.083</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 10643.767 K
# 	Expected t_inner for next iteration = 10653.605 K
#  (base.py:652)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 13 of 20 (base.py:444)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 1.062e+43 erg / s
# 	Luminosity absorbed  = 3.401e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:657)
# [tardis.simulation.base][INFO   ]
# 	Iteration converged 11/4 consecutive times. (base.py:260)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:625)
# <style type="text/css">
# </style>
# <table id="T_5293f">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_5293f_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_5293f_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_5293f_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_5293f_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5293f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5293f_row0_col0" class="data row0 col0" >1.11e+04 K</td>
#       <td id="T_5293f_row0_col1" class="data row0 col1" >1.11e+04 K</td>
#       <td id="T_5293f_row0_col2" class="data row0 col2" >0.464</td>
#       <td id="T_5293f_row0_col3" class="data row0 col3" >0.461</td>
#     </tr>
#     <tr>
#       <th id="T_5293f_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_5293f_row1_col0" class="data row1 col0" >1.13e+04 K</td>
#       <td id="T_5293f_row1_col1" class="data row1 col1" >1.13e+04 K</td>
#       <td id="T_5293f_row1_col2" class="data row1 col2" >0.178</td>
#       <td id="T_5293f_row1_col3" class="data row1 col3" >0.177</td>
#     </tr>
#     <tr>
#       <th id="T_5293f_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_5293f_row2_col0" class="data row2 col0" >1.11e+04 K</td>
#       <td id="T_5293f_row2_col1" class="data row2 col1" >1.1e+04 K</td>
#       <td id="T_5293f_row2_col2" class="data row2 col2" >0.11</td>
#       <td id="T_5293f_row2_col3" class="data row2 col3" >0.114</td>
#     </tr>
#     <tr>
#       <th id="T_5293f_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_5293f_row3_col0" class="data row3 col0" >1.08e+04 K</td>
#       <td id="T_5293f_row3_col1" class="data row3 col1" >1.07e+04 K</td>
#       <td id="T_5293f_row3_col2" class="data row3 col2" >0.083</td>
#       <td id="T_5293f_row3_col3" class="data row3 col3" >0.0856</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 10653.605 K
# 	Expected t_inner for next iteration = 10646.038 K
#  (base.py:652)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 14 of 20 (base.py:444)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 1.063e+43 erg / s
# 	Luminosity absorbed  = 3.361e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:657)
# [tardis.simulation.base][INFO   ]
# 	Iteration converged 12/4 consecutive times. (base.py:260)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:625)
# <style type="text/css">
# </style>
# <table id="T_8e863">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_8e863_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_8e863_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_8e863_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_8e863_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8e863_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8e863_row0_col0" class="data row0 col0" >1.11e+04 K</td>
#       <td id="T_8e863_row0_col1" class="data row0 col1" >1.11e+04 K</td>
#       <td id="T_8e863_row0_col2" class="data row0 col2" >0.461</td>
#       <td id="T_8e863_row0_col3" class="data row0 col3" >0.466</td>
#     </tr>
#     <tr>
#       <th id="T_8e863_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_8e863_row1_col0" class="data row1 col0" >1.13e+04 K</td>
#       <td id="T_8e863_row1_col1" class="data row1 col1" >1.13e+04 K</td>
#       <td id="T_8e863_row1_col2" class="data row1 col2" >0.177</td>
#       <td id="T_8e863_row1_col3" class="data row1 col3" >0.181</td>
#     </tr>
#     <tr>
#       <th id="T_8e863_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_8e863_row2_col0" class="data row2 col0" >1.1e+04 K</td>
#       <td id="T_8e863_row2_col1" class="data row2 col1" >1.1e+04 K</td>
#       <td id="T_8e863_row2_col2" class="data row2 col2" >0.114</td>
#       <td id="T_8e863_row2_col3" class="data row2 col3" >0.113</td>
#     </tr>
#     <tr>
#       <th id="T_8e863_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_8e863_row3_col0" class="data row3 col0" >1.07e+04 K</td>
#       <td id="T_8e863_row3_col1" class="data row3 col1" >1.07e+04 K</td>
#       <td id="T_8e863_row3_col2" class="data row3 col2" >0.0856</td>
#       <td id="T_8e863_row3_col3" class="data row3 col3" >0.0849</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 10646.038 K
# 	Expected t_inner for next iteration = 10637.734 K
#  (base.py:652)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 15 of 20 (base.py:444)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 1.054e+43 erg / s
# 	Luminosity absorbed  = 3.403e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:657)
# [tardis.simulation.base][INFO   ]
# 	Iteration converged 13/4 consecutive times. (base.py:260)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:625)
# <style type="text/css">
# </style>
# <table id="T_e3af9">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_e3af9_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_e3af9_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_e3af9_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_e3af9_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3af9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e3af9_row0_col0" class="data row0 col0" >1.11e+04 K</td>
#       <td id="T_e3af9_row0_col1" class="data row0 col1" >1.1e+04 K</td>
#       <td id="T_e3af9_row0_col2" class="data row0 col2" >0.466</td>
#       <td id="T_e3af9_row0_col3" class="data row0 col3" >0.479</td>
#     </tr>
#     <tr>
#       <th id="T_e3af9_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_e3af9_row1_col0" class="data row1 col0" >1.13e+04 K</td>
#       <td id="T_e3af9_row1_col1" class="data row1 col1" >1.13e+04 K</td>
#       <td id="T_e3af9_row1_col2" class="data row1 col2" >0.181</td>
#       <td id="T_e3af9_row1_col3" class="data row1 col3" >0.179</td>
#     </tr>
#     <tr>
#       <th id="T_e3af9_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_e3af9_row2_col0" class="data row2 col0" >1.1e+04 K</td>
#       <td id="T_e3af9_row2_col1" class="data row2 col1" >1.11e+04 K</td>
#       <td id="T_e3af9_row2_col2" class="data row2 col2" >0.113</td>
#       <td id="T_e3af9_row2_col3" class="data row2 col3" >0.11</td>
#     </tr>
#     <tr>
#       <th id="T_e3af9_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_e3af9_row3_col0" class="data row3 col0" >1.07e+04 K</td>
#       <td id="T_e3af9_row3_col1" class="data row3 col1" >1.07e+04 K</td>
#       <td id="T_e3af9_row3_col2" class="data row3 col2" >0.0849</td>
#       <td id="T_e3af9_row3_col3" class="data row3 col3" >0.0839</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 10637.734 K
# 	Expected t_inner for next iteration = 10652.014 K
#  (base.py:652)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 16 of 20 (base.py:444)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 1.057e+43 erg / s
# 	Luminosity absorbed  = 3.452e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:657)
# [tardis.simulation.base][INFO   ]
# 	Iteration converged 14/4 consecutive times. (base.py:260)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:625)
# <style type="text/css">
# </style>
# <table id="T_8ae48">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_8ae48_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_8ae48_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_8ae48_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_8ae48_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8ae48_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8ae48_row0_col0" class="data row0 col0" >1.1e+04 K</td>
#       <td id="T_8ae48_row0_col1" class="data row0 col1" >1.1e+04 K</td>
#       <td id="T_8ae48_row0_col2" class="data row0 col2" >0.479</td>
#       <td id="T_8ae48_row0_col3" class="data row0 col3" >0.472</td>
#     </tr>
#     <tr>
#       <th id="T_8ae48_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_8ae48_row1_col0" class="data row1 col0" >1.13e+04 K</td>
#       <td id="T_8ae48_row1_col1" class="data row1 col1" >1.13e+04 K</td>
#       <td id="T_8ae48_row1_col2" class="data row1 col2" >0.179</td>
#       <td id="T_8ae48_row1_col3" class="data row1 col3" >0.175</td>
#     </tr>
#     <tr>
#       <th id="T_8ae48_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_8ae48_row2_col0" class="data row2 col0" >1.11e+04 K</td>
#       <td id="T_8ae48_row2_col1" class="data row2 col1" >1.11e+04 K</td>
#       <td id="T_8ae48_row2_col2" class="data row2 col2" >0.11</td>
#       <td id="T_8ae48_row2_col3" class="data row2 col3" >0.112</td>
#     </tr>
#     <tr>
#       <th id="T_8ae48_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_8ae48_row3_col0" class="data row3 col0" >1.07e+04 K</td>
#       <td id="T_8ae48_row3_col1" class="data row3 col1" >1.08e+04 K</td>
#       <td id="T_8ae48_row3_col2" class="data row3 col2" >0.0839</td>
#       <td id="T_8ae48_row3_col3" class="data row3 col3" >0.0826</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 10652.014 K
# 	Expected t_inner for next iteration = 10658.752 K
#  (base.py:652)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 17 of 20 (base.py:444)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 1.065e+43 erg / s
# 	Luminosity absorbed  = 3.404e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:657)
# [tardis.simulation.base][INFO   ]
# 	Iteration converged 15/4 consecutive times. (base.py:260)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:625)
# <style type="text/css">
# </style>
# <table id="T_a097c">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_a097c_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_a097c_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_a097c_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_a097c_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a097c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a097c_row0_col0" class="data row0 col0" >1.1e+04 K</td>
#       <td id="T_a097c_row0_col1" class="data row0 col1" >1.11e+04 K</td>
#       <td id="T_a097c_row0_col2" class="data row0 col2" >0.472</td>
#       <td id="T_a097c_row0_col3" class="data row0 col3" >0.466</td>
#     </tr>
#     <tr>
#       <th id="T_a097c_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_a097c_row1_col0" class="data row1 col0" >1.13e+04 K</td>
#       <td id="T_a097c_row1_col1" class="data row1 col1" >1.14e+04 K</td>
#       <td id="T_a097c_row1_col2" class="data row1 col2" >0.175</td>
#       <td id="T_a097c_row1_col3" class="data row1 col3" >0.175</td>
#     </tr>
#     <tr>
#       <th id="T_a097c_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_a097c_row2_col0" class="data row2 col0" >1.11e+04 K</td>
#       <td id="T_a097c_row2_col1" class="data row2 col1" >1.12e+04 K</td>
#       <td id="T_a097c_row2_col2" class="data row2 col2" >0.112</td>
#       <td id="T_a097c_row2_col3" class="data row2 col3" >0.107</td>
#     </tr>
#     <tr>
#       <th id="T_a097c_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_a097c_row3_col0" class="data row3 col0" >1.08e+04 K</td>
#       <td id="T_a097c_row3_col1" class="data row3 col1" >1.08e+04 K</td>
#       <td id="T_a097c_row3_col2" class="data row3 col2" >0.0826</td>
#       <td id="T_a097c_row3_col3" class="data row3 col3" >0.0814</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 10658.752 K
# 	Expected t_inner for next iteration = 10644.103 K
#  (base.py:652)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 18 of 20 (base.py:444)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 1.060e+43 erg / s
# 	Luminosity absorbed  = 3.377e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:657)
# [tardis.simulation.base][INFO   ]
# 	Iteration converged 16/4 consecutive times. (base.py:260)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:625)
# <style type="text/css">
# </style>
# <table id="T_cf690">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_cf690_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_cf690_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_cf690_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_cf690_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cf690_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cf690_row0_col0" class="data row0 col0" >1.11e+04 K</td>
#       <td id="T_cf690_row0_col1" class="data row0 col1" >1.11e+04 K</td>
#       <td id="T_cf690_row0_col2" class="data row0 col2" >0.466</td>
#       <td id="T_cf690_row0_col3" class="data row0 col3" >0.464</td>
#     </tr>
#     <tr>
#       <th id="T_cf690_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_cf690_row1_col0" class="data row1 col0" >1.14e+04 K</td>
#       <td id="T_cf690_row1_col1" class="data row1 col1" >1.14e+04 K</td>
#       <td id="T_cf690_row1_col2" class="data row1 col2" >0.175</td>
#       <td id="T_cf690_row1_col3" class="data row1 col3" >0.172</td>
#     </tr>
#     <tr>
#       <th id="T_cf690_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_cf690_row2_col0" class="data row2 col0" >1.12e+04 K</td>
#       <td id="T_cf690_row2_col1" class="data row2 col1" >1.11e+04 K</td>
#       <td id="T_cf690_row2_col2" class="data row2 col2" >0.107</td>
#       <td id="T_cf690_row2_col3" class="data row2 col3" >0.109</td>
#     </tr>
#     <tr>
#       <th id="T_cf690_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_cf690_row3_col0" class="data row3 col0" >1.08e+04 K</td>
#       <td id="T_cf690_row3_col1" class="data row3 col1" >1.07e+04 K</td>
#       <td id="T_cf690_row3_col2" class="data row3 col2" >0.0814</td>
#       <td id="T_cf690_row3_col3" class="data row3 col3" >0.083</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 10644.103 K
# 	Expected t_inner for next iteration = 10642.546 K
#  (base.py:652)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 19 of 20 (base.py:444)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 1.053e+43 erg / s
# 	Luminosity absorbed  = 3.432e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:657)
# [tardis.simulation.base][INFO   ]
# 	Iteration converged 17/4 consecutive times. (base.py:260)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:625)
# <style type="text/css">
# </style>
# <table id="T_75917">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_75917_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_75917_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_75917_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_75917_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75917_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_75917_row0_col0" class="data row0 col0" >1.11e+04 K</td>
#       <td id="T_75917_row0_col1" class="data row0 col1" >1.11e+04 K</td>
#       <td id="T_75917_row0_col2" class="data row0 col2" >0.464</td>
#       <td id="T_75917_row0_col3" class="data row0 col3" >0.464</td>
#     </tr>
#     <tr>
#       <th id="T_75917_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_75917_row1_col0" class="data row1 col0" >1.14e+04 K</td>
#       <td id="T_75917_row1_col1" class="data row1 col1" >1.14e+04 K</td>
#       <td id="T_75917_row1_col2" class="data row1 col2" >0.172</td>
#       <td id="T_75917_row1_col3" class="data row1 col3" >0.175</td>
#     </tr>
#     <tr>
#       <th id="T_75917_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_75917_row2_col0" class="data row2 col0" >1.11e+04 K</td>
#       <td id="T_75917_row2_col1" class="data row2 col1" >1.12e+04 K</td>
#       <td id="T_75917_row2_col2" class="data row2 col2" >0.109</td>
#       <td id="T_75917_row2_col3" class="data row2 col3" >0.109</td>
#     </tr>
#     <tr>
#       <th id="T_75917_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_75917_row3_col0" class="data row3 col0" >1.07e+04 K</td>
#       <td id="T_75917_row3_col1" class="data row3 col1" >1.08e+04 K</td>
#       <td id="T_75917_row3_col2" class="data row3 col2" >0.083</td>
#       <td id="T_75917_row3_col3" class="data row3 col3" >0.0821</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 10642.546 K
# 	Expected t_inner for next iteration = 10657.504 K
#  (base.py:652)
# [tardis.simulation.base][INFO   ]
#
# 	Simulation finished in 19 iterations
# 	Simulation took 16.43 s
#  (base.py:542)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 20 of 20 (base.py:444)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 1.061e+43 erg / s
# 	Luminosity absorbed  = 3.434e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:657)

# %% [markdown]
# Now, import functions & class to create widgets from visualizationvisualization subpackage:

# %%
import panel as pn
from tardis.visualization import shell_info_from_simulation

# %% [markdown]
# ## Shell Info Widget
#
# This widget allows you to explore chemical abundances of each shell - all the way from elements to ions to levels - by just clicking on the rows you want to explore!
#
# There are two ways in which you can generate the widget:

# %% [markdown]
# ### Using a Simulation object
#
# We will use the simulation object we created in the beginning, simsim to generate shell info widget. Then simply display it to start using.

# %%
widget = shell_info_from_simulation(sim)
widget.get_panel().servable()
# Out:
# Column(sizing_mode='stretch_width', styles={'padding': '20px', ...})
#     [0] Markdown(str, styles={'font-size': '24px', ...})
#     [1] HTML(str, width=400)
#     [2] Row(scroll=True, sizing_mode='stretch_width', styles={'margin': '15px', ...})
#         [0] Column(styles={'padding': '15px', ...}, width=350)
#             [0] Markdown(str, margin=(0, 0, 10, 0), styles={'font-size': '16px', ...})
#             [1] Tabulator(header_align='center', layout='fit_data', selection=[0], styles={'border': '1px solid #ddd...}, text_align='center', titles={'Shell No.': 'Shell No.',...}, value=             R..., widths={'Shell No.': 100, ...})
#         [1] Column(styles={'padding': '15px', ...}, width=350)
#             [0] Markdown(str, margin=(0, 0, 10, 0), styles={'font-size': '16px', ...})
#             [1] Tabulator(header_align='center', layout='fit_data', selection=[0], styles={'border': '1px solid #ddd...}, text_align='center', value=   Element Frac. A..., widths={'Element': 120, ...})
#         [2] Column(styles={'padding': '15px', ...}, width=400)
#             [0] Markdown(str, margin=(0, 0, 10, 0), styles={'font-size': '16px', ...})
#             [1] Tabulator(header_align='center', layout='fit_data', selection=[0], styles={'border': '1px solid #ddd...}, text_align='center', value=    Species Frac. A..., widths={'Species': 180, ...})
#         [3] Column(styles={'padding': '15px', ...}, width=400)
#             [0] Markdown(str, margin=(0, 0, 10, 0), styles={'font-size': '16px', ...})
#             [1] Tabulator(header_align='center', layout='fit_data', selection=[0], styles={'border': '1px solid #ddd...}, text_align='center', value=      Frac. Ab. (..., widths={'Level': 120, ...})

# %% [markdown]
# You can interact with the widget produced in output above (which won't be visible if you're viewing this notebook in our docs as an html page) like this:
#
# ![Shell Info Widget Demo](../images/shell_info_widget_demo.gif)
#
# Use the button at the top of this page to run the notebook in interactively to use the widgets!

# %% [markdown]
# ### Using a saved simulation (HDF file)
#
# Alternatively, if you have a TARDIS simulation model saved on your disk as an HDF file, you can also use it to generate the shell info widget.

# %%
# shell_info_widget = shell_info_from_hdf('demo.h5')
# shell_info_widget.display()

# %% [markdown]
# ## Line Info Widget
#
# This widget lets you explore the atomic lines responsible for producing features in the simulated spectrum.
#
# You can select any wavelength range in the spectrum interactively to display a table giving the fraction of packets that experienced their last interaction with each species. Using toggle buttons, you can specify whether to filter the selected range by the emitted or absorbed wavelengths of packets. Clicking on a row in the species table, shows packet counts for each last line interaction of the selected species, which can be grouped in several ways.

# %% [markdown]
# To generate line info widget, we will again use the simulation object simsim and then display the widget:

# %%
line_info_widget = LineInfoWidget.from_simulation(sim)
line_info_widget.display()

# %% [markdown]
# You can interact with this widget (which again won't be visible if you're viewing this notebook in our docs as an html page) like this:
#
# ![Line Info Widget Demo](../images/line_info_widget_demo.gif)

# %% [markdown]
# <div class="alert alert-info">
#
# Note
#
# The virtual packet logging capability must be active in order to produce virtual packets' spectrum in `Line Info Widget`. Thus, make sure to set `virtual_packet_logging: True` in your configuration file. It should be added under `virtual` property of `spectrum` property, as described in [configuration schema](https://tardis-sn.github.io/tardis/using/components/configuration/configuration.html#spectrum).
#
# </div>

# %% [markdown]
# ## Energy Level Diagram
#
# This widget lets you explore and visualize the various level populations and line interactions in a simulation in the form of an Energy Level Diagram.
#
# You can select any ion present in the simulation and filter the transitions by wavelength or model shell to display an energy level diagram, where:
#
# - The horizontal lines represent the energy levels. The thickness of each line shows the relative population of that energy level, with thicker lines being more populated.
# - The arrows represent the line interactions between levels, with the arrow direction giving the direction of the transition. The thickness of each arrow also shows the number of packets that underwent the transition while the wavelength is given by the color.
#
# In addition, you can also select between linear- and log-scaling for the y-axis (which represents the energy of each level) and the maximum number of levels to display, beginning from the lowest energy levels.

# %% [markdown]
# To generate the energy level diagram, we will again use the simulation object `sim` and then display the widget:

# %%
energy_level_widget = GrotrianWidget.from_simulation(sim)
energy_level_widget.display()

# %% [markdown]
# You can interact with this widget (which again won't be visible if you're viewing this notebook in our docs as an html page) like this:
#
# ![Energy Level Diagram Demo](../images/energy_level_widget_options.gif)
