# %%
#importing our necessary modules
from tardis import run_tardis
from tardis.io.atom_data.util import download_atom_data

import networkx as nx
# Out:
# /home/matt_2/anaconda3/envs/tardis/lib/python3.7/importlib/_bootstrap.py:219: QAWarning: pyne.data is not yet QA compliant.
#   return f(*args, **kwds)
# Iterations:          0/? [00:00<?, ?it/s]
# Packets:             0/? [00:00<?, ?it/s]

# %%
download_atom_data('kurucz_cd23_chianti_H_He')

# %%
sim = run_tardis('tardis_example.yml')
# Out:
# [py.warnings         ][WARNING]  /home/matt_2/tardis/tardis/plasma/properties/radiative_properties.py:92: RuntimeWarning: invalid value encountered in true_divide
#   (g_lower * n_upper) / (g_upper * n_lower)
#  (warnings.py:110)
# [py.warnings         ][WARNING]  /home/matt_2/tardis/tardis/plasma/properties/radiative_properties.py:92: RuntimeWarning: invalid value encountered in true_divide
#   (g_lower * n_upper) / (g_upper * n_lower)
#  (warnings.py:110)
# TqdmHBox(children=(HTML(value='Iterations:', layout=Layout(width='6%')), FloatProgress(value=0.0, layout=Layou…
# TqdmHBox(children=(HTML(value='Packets:   ', layout=Layout(width='6%')), FloatProgress(value=0.0, layout=Layou…
# [py.warnings         ][WARNING]  /home/matt_2/tardis/tardis/plasma/properties/radiative_properties.py:92: RuntimeWarning: invalid value encountered in true_divide
#   (g_lower * n_upper) / (g_upper * n_lower)
#  (warnings.py:110)
# ...

# %%
open("Plasma_Graph.dot", "r").readlines()
# Out:
# ['strict digraph "" {\n',
#  '\tratio="fill";\n',
#  '\tsize="8.3,11.7!";\n',
#  '\tmargin=0;\n',
#  '\tnode [texmode="math"];\n',
#  '\tedge[lblstyle="fill=white"];\n',
#  '\tTRadiative\t[label="\\\\textrm{TRadiative}"];\n',
#  '\tBetaRadiation\t[label="\\\\textrm{BetaRadiation: }\\\\dfrac{1}{k_{B} T_{\\\\textrm{rad}}}"];\n',
#  '\tTRadiative -> BetaRadiation\t[label="-",\n',
#  '\t\tminlen=2.881083273381583,\n',
#  '\t\ttexlbl="$T_{\\\\textrm{rad}}$"];\n',
#  '\tElectronTemperature\t[label="\\\\textrm{ElectronTemperature: }\\\\textrm{const.}\\\\times T_{\\\\textrm{rad}}"];\n',
#  '\tTRadiative -> ElectronTemperature\t[label="-",\n',
#  '\t\tminlen=9.428616692053867,\n',
#  '\t\ttexlbl="$T_{\\\\textrm{rad}}$"];\n',
#  '\tJBluesDiluteBlackBody\t[label="\\\\textrm{JBluesDiluteBlackBody}"];\n',
#  '\tTRadiative -> JBluesDiluteBlackBody\t[label="-",\n',
#  '\t\tminlen=4.493621660730429,\n',
#  '\t\ttexlbl="$T_{\\\\textrm{rad}}$"];\n',
# ...

# %%
sim.plasma.write_to_dot("Plasma_Graph_Copy.dot")

# %%
# %pylab notebook

pos = nx.spring_layout(sim.plasma.graph, k=0.75, iterations=15)

nx.draw(sim.plasma.graph, pos, with_labels=True)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <img src="data:image/png;base64,..." width="640">
