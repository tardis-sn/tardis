# %% [markdown]
# # Non-Homologous TARDIS Workflow

# %%
from numba import config as nbconfig

nbconfig.DISABLE_JIT = False

# %%
import matplotlib.pyplot as plt

from tardis.io.configuration.config_reader import Configuration
from tardis.workflows.nonhomologous_tardis_workflow import (
    NonhomologousTARDISWorkflow,
)
from tardis.workflows.simple_tardis_workflow import SimpleTARDISWorkflow
# Out:
# Iterations:          0/? [00:00<?, ?it/s]
# Packets:             0/? [00:00<?, ?it/s]
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.32.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.1/MathJax.js?config=TeX-MML-AM_SVG"></script>
# Initializing tabulator and plotly panel extensions for widgets to work
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='494f66f9-1619-452a-9dcb-4dd378bb4c4c'>
#   <div id="bff90607-46f9-403c-b724-cabdd4ca9e7f" data-root-id="494f66f9-1619-452a-9dcb-4dd378bb4c4c" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"8fdfd404-e1af-4a39-ad03-d1e4288b47a0":{"version":"3.7.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"494f66f9-1619-452a-9dcb-4dd378bb4c4c"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"79e6d5d6-73d3-45a6-bcfa-37a9b5f5d3d5","attributes":{"plot_id":"494f66f9-1619-452a-9dcb-4dd378bb4c4c","comm_id":"31448c8166054182ae1d9207e7764fd6","client_comm_id":"f6683959414b4b188d1c9f7df0c1a6f7"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1" ...
#   var render_items = [{"docid":"8fdfd404-e1af-4a39-ad03-d1e4288b47a0","roots":{"494f66f9-1619-452a-9dcb-4dd378bb4c4c":"bff90607-46f9-403c-b724-cabdd4ca9e7f"},"root_ids":["494f66f9-1619-452a-9dcb-4dd378bb4c4c"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root.Tabulator !== undefined) && ( root.Plotly !== undefined) && ( root.Tabulator !== undefined) && ( root.Plotly !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# Auto-detected VSCode environment
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# Auto-detected VSCode environment
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
config = Configuration.from_yaml('../tardis_example.yml')
config.montecarlo['enable_full_relativity'] = False

# %%
workflow = NonhomologousTARDISWorkflow(config)
hom_workflow = SimpleTARDISWorkflow(config)
# Out:
# BokehModel(combine_events=True, render_bundle={'docs_json': {'62725a65-7078-41f2-9794-8adb805de877': {'version…
# BokehModel(combine_events=True, render_bundle={'docs_json': {'73f29ba9-e6d3-4641-beed-612f82eeb114': {'version…

# %%
workflow.run()
# Out:
# No real roots found in depressed_quartic solver. Smallest term is -0.0040865917831069964 (greater than relative threshold for zeroing, which is 0.0009381132340626381 ). Bending threshold for this root and forcing to zero. Threshold is currently 3e-07 and would need to be greater than 1.3068545356969561e-06 to catch this case.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 workflow.run()
#
# File ~/tardis-dev/tardis/workflows/nonhomologous_tardis_workflow.py:532, in NonhomologousTARDISWorkflow.run(self)
#     526 logger.info(
#     527     f"\n\tStarting iteration {(self.completed_iterations + 1):d} of {self.total_iterations:d}"
#     528 )
#     530 self.opacity_states = self.solve_opacity()
# --> 532 virtual_packet_energies = self.solve_montecarlo(
#     533     self.opacity_states, self.real_packet_count
#     534 )
#     536 (
#     537     estimated_values,
#     538     estimated_radfield_properties,
#     539 ) = self.get_convergence_estimates()
#     541 self.solve_simulation_state(estimated_values)
#
# File ~/tardis-dev/tardis/workflows/nonhomologous_tardis_workflow.py:463, in NonhomologousTARDISWorkflow.solve_montecarlo(self, opacity_states, no_of_real_packets, no_of_virtual_packets)
#     451 macro_atom_state = opacity_states["macro_atom_state"]
#     453 self.transport_state = self.transport_solver.initialize_transport_state(
#     454     self.simulation_state,
#     455     opacity_state,
#    (...)    460     iteration=self.completed_iterations,
#     461 )
# --> 463 virtual_packet_energies = self.transport_solver.run(
#     464     self.transport_state,
#     465     show_progress_bars=self.show_progress_bars,
#     466 )
#     468 output_energy = self.transport_state.packet_collection.output_energies
#     469 if np.sum(output_energy < 0) == len(output_energy):
#
# File ~/tardis-dev/tardis/transport/montecarlo/modes/nonhomologous/solver.py:167, in MCTransportSolverNonhomologous.run(self, transport_state, show_progress_bars)
#     147 def run(
#     148     self,
#     149     transport_state,
#     150     show_progress_bars=True,
#     151 ):
#     152     """
#     153     Run the montecarlo calculation.
#     154
#    (...)    165         Histogram of energy from virtual packets
#     166     """
# --> 167     return self.run_nonhomologous(transport_state, show_progress_bars)
#
# File ~/tardis-dev/tardis/transport/montecarlo/modes/nonhomologous/solver.py:216, in MCTransportSolverNonhomologous.run_nonhomologous(self, transport_state, show_progress_bars)
#     208     reset_packet_pbar(number_of_rpackets)
#     210 # nonhomologous mode: returns 4 values (no continuum estimators)
#     211 (
#     212     v_packets_energy_hist,
#     213     vpacket_tracker,
#     214     estimators_bulk,
#     215     estimators_line,
# --> 216 ) = montecarlo_transport(
#     217     transport_state.packet_collection,
#     218     transport_state.geometry_state,
#     219     transport_state.opacity_state,
#     220     self.montecarlo_configuration,
#     221     self.spectrum_frequency_grid.value,
#     222     trackers_list,
#     223     number_of_vpackets,
#     224     show_progress_bars=show_progress_bars,
#     225 )
#     227 # Attach estimators to transport state
#     228 transport_state.estimators_bulk = estimators_bulk
#
# File ~/tardis-dev/tardis/transport/montecarlo/modes/nonhomologous/montecarlo_transport.py:164, in montecarlo_transport(packet_collection, geometry_state_numba, opacity_state_numba, montecarlo_configuration, spectrum_frequency_grid, trackers, number_of_vpackets, show_progress_bars)
#     161 # RPacket Tracker for this thread
#     162 tracker = trackers[i]
# --> 164 loop = packet_propagation(
#     165     r_packet,
#     166     geometry_state_numba,
#     167     opacity_state_numba,
#     168     estimators_bulk_thread,
#     169     estimators_line_thread,
#     170     vpacket_collection,
#     171     tracker,
#     172     montecarlo_configuration,
#     173 )
#     174 packet_collection.output_nus[i] = r_packet.nu
#     176 if r_packet.status == PacketStatus.REABSORBED:
#
# File ~/tardis-dev/tardis/transport/montecarlo/modes/nonhomologous/packet_propagation.py:151, in packet_propagation(r_packet, numba_radial_1d_geometry, opacity_state, estimators_bulk, estimators_line, vpacket_collection, rpacket_tracker, montecarlo_configuration)
#     148 if montecarlo_configuration.ENABLE_FULL_RELATIVITY:
#     149     opacity_electron *= doppler_factor
# --> 151 distance, interaction_type, delta_shell = trace_packet(
#     152     r_packet,
#     153     numba_radial_1d_geometry,
#     154     opacity_state,
#     155     estimators_line,
#     156     opacity_electron,
#     157     montecarlo_configuration.ENABLE_FULL_RELATIVITY,
#     158     montecarlo_configuration.DISABLE_LINE_SCATTERING,
#     159 )
#     161 if interaction_type == InteractionType.BOUNDARY:
#     162     move_r_packet(
#     163         r_packet,
#     164         distance,
#    (...)    167         montecarlo_configuration.ENABLE_FULL_RELATIVITY,
#     168     )
#
# File ~/tardis-dev/tardis/transport/montecarlo/modes/nonhomologous/rad_packet_transport.py:120, in trace_packet(r_packet, numba_radial_1d_geometry, opacity_state, estimators_line, opacity_electron, enable_full_relativity, disable_line_scattering)
#     116 # Calculating the distance until the current photons co-moving nu
#     117 # redshifts to the line frequency
#     118 is_last_line = cur_line_id == last_line_id
# --> 120 distance_trace = calculate_distance_line_nonhomologous(
#     121     r_packet,
#     122     numba_radial_1d_geometry,
#     123     nu_line,
#     124 )
#     126 # calculating the tau electron of how far the trace has progressed
#     127 tau_trace_electron = opacity_electron * distance_trace
#
# File ~/tardis-dev/tardis/transport/geometry/calculate_distances.py:181, in calculate_distance_line_nonhomologous(rpacket, geometry, nu_line)
#     177 comov_nu = nu_rest * doppler_factor
#     179 if (comov_nu - nu_line > 1e-14*nu_line and m > 0.0) or (comov_nu - nu_line < -1e-14*nu_line and m < 0.0):
#     180     # Obtain roots of the quartic polynomial for x (= d_line + r_i \mu_i)
# --> 181     x = depressed_quartic(a, b, c, d, e)
#     182     # Convert each root x_i to a candidate distance: d = r0*x_i - r*mu
#     183     # Select the smallest positive, finite distance among all four roots.
#     184     distance = MISS_DISTANCE
#
# File ~/tardis-dev/tardis/transport/montecarlo/nonhomologous_grid.py:47, in depressed_quartic(A, B, C, D, E)
#      45 q2p3_term = q**2.0/(4.0) + p**3.0/27.0
#      46 q2p3_complex = q2p3_term + 0j
# ---> 47 r = -q/2 + np.sqrt(q2p3_complex)
#      48 u = r**(1./3.)
#      50 # Handle case where u=0
#
# KeyboardInterrupt:

# %%
hom_workflow.run()

# %%
spectrum = workflow.spectrum_solver.spectrum_real_packets
spectrum_virtual = workflow.spectrum_solver.spectrum_virtual_packets
spectrum_integrated = workflow.spectrum_solver.spectrum_integrated
hom_spectrum = hom_workflow.spectrum_solver.spectrum_real_packets
hom_spectrum_virtual = hom_workflow.spectrum_solver.spectrum_virtual_packets
hom_spectrum_integrated = workflow.spectrum_solver.spectrum_integrated

# %%
# %matplotlib inline
plt.figure(figsize=(10, 6.5))

spectrum.plot(label="Normal packets, non-homology", c='C0', alpha=0.1)
hom_spectrum.plot(label="Normal packets, homology", c='C1', alpha=0.1)

spectrum_virtual.plot(linewidth=3, c='w', alpha=1.0)
hom_spectrum_virtual.plot(linewidth=4, c='w', alpha=1.0)
spectrum_virtual.plot(label="Virtual packets, non-homology", c='C0', alpha=0.35)
hom_spectrum_virtual.plot(label="Virtual packets, homology", c='C1', alpha=0.35)

spectrum_integrated.plot(linewidth=3, c='w', alpha=1.0)
spectrum_integrated.plot(label="Formal Integral, non-homology", c='C0', alpha=1.0)
hom_spectrum_integrated.plot(label="Formal Integral, homology", c='C1', alpha=1.0, linestyle='--')


plt.xlim(500, 9000)
plt.title("TARDIS example model spectrum")
plt.xlabel(r"Wavelength [$\AA$]")
plt.ylabel(r"Luminosity density [erg/s/$\AA$]")
plt.legend()
plt.show()
