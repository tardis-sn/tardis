# %%
from tardis import run_tardis
import cProfile

# %%
cProfile.run('run_tardis("tardis_example.yml")','main.cprof')
# Out:
# [tardis.plasma.standard_plasmas][INFO   ]  Reading Atomic Data from kurucz_cd23_chianti_H_He.h5 (standard_plasmas.py:74)
# [tardis.io.atom_data.util][INFO   ]  Atom Data kurucz_cd23_chianti_H_He.h5 not found in local path. Exists in TARDIS Data repo /home/jordi/TARDIS/tardis-data/kurucz_cd23_chianti_H_He.h5 (util.py:29)
# [py.warnings         ][WARNING]  /home/jordi/anaconda3/envs/tardis/lib/python3.6/cProfile.py:100: PerformanceWarning: indexing past lexsort depth may impact performance.
#   exec(cmd, globals, locals)
#  (warnings.py:99)
# [tardis.io.atom_data.base][INFO   ]  Read Atom Data with UUID=6f7b09e887a311e7a06b246e96350010 and MD5=864f1753714343c41f99cb065710cace. (base.py:184)
# [tardis.io.atom_data.base][INFO   ]  Non provided atomic data: synpp_refs, photoionization_data (base.py:187)
# [tardis.simulation.base][INFO   ]  Starting iteration 1/20 (base.py:268)
# ...

# %% [markdown]
# main.cprof --> 'ran_tardis'

# %%
import pstats
p = pstats.Stats('main.cprof')
p.sort_stats('time').print_stats(20)
# Out:
# Sat Feb 29 20:03:42 2020    main.cprof
#
#          1725783 function calls (1698090 primitive calls) in 44.753 seconds
#
#    Ordered by: internal time
#    List reduced from 2085 to 20 due to restriction <20>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        20   40.150    2.008   40.185    2.009 {tardis.montecarlo.montecarlo.montecarlo_radial1d}
#        43    0.697    0.016    1.259    0.029 {method 'get_indexer' of 'pandas._libs.index.BaseMultiIndexCodesEngine' objects}
#        31    0.283    0.009    0.283    0.009 {pandas._libs.lib.fast_zip}
#        21    0.279    0.013    0.279    0.013 {tardis.plasma.properties.util.macro_atom.calculate_transition_probabilities}
#        62    0.246    0.004    0.249    0.004 /home/jordi/anaconda3/envs/tardis/lib/python3.6/site-packages/numexpr/necompiler.py:765(evaluate)
# 8762/8404    0.117    0.000    0.122    0.000 {built-in method numpy.core.multiarray.array}
# ...

# %%
p.print_callers(.5, 'init')
# Out:
#    Ordered by: internal time
#    List reduced from 2085 to 1043 due to restriction <0.5>
#    List reduced from 1043 to 67 due to restriction <'init'>
#
# Function                                                                                                                was called by...
#                                                                                                                             ncalls  tottime  cumtime
# /home/jordi/anaconda3/envs/tardis/lib/python3.6/site-packages/pandas/core/series.py:152(__init__)                       <-      21    0.000    0.003  /home/jordi/anaconda3/envs/tardis/lib/python3.6/site-packages/pandas/core/dtypes/missing.py:183(_isna_ndarraylike)
#                                                                                                                                152    0.001    0.004  /home/jordi/anaconda3/envs/tardis/lib/python3.6/site-packages/pandas/core/frame.py:3349(_box_col_values)
# ...
