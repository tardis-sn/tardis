# %% [markdown]
# # Energy Packet Filtering and Visualization Dashboard
#
# This interactive dashboard allows you to:
#
# - **Select an atomic number** from the dropdown menu.
# - **View a histogram** of the energy packet wavelengths that originated from that atomic number.
# - **Explore trends** in the spectral output of different elements in your TARDIS simulation.
#
# > If no packets are found for a selected atomic number, a message will be shown.
#
# You can scroll or hover on the histogram for more detail.

# %%
from energy_packet_filtering import build_dashboard
import panel as pn
pn.extension("plotly")

dashboard = build_dashboard()
dashboard.servable()
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='99d05b25-9d08-4d47-90c7-0f76d172887c'>
#   <div id="c686bd9a-7075-45b2-956b-b17cb0188e73" data-root-id="99d05b25-9d08-4d47-90c7-0f76d172887c" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...
