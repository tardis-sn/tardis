# %% [markdown]
# # Using Custom Callbacks When Running TARDIS

# %% [markdown]
# The function `run_tardis` allows users to provide a set of callbacks to the simulation. These callbacks are functions that will be run at the end of each iteration, and can do a variety of things, such as printing information about the simulation, storing data to a table, or even changing simulation parameters between iterations. This tutorial will show three examples of callbacks and how they can be used in TARDIS. One important thing to note is that the first argument of the callback must be the `Simulation` object being run.
#
# Our first callback example will compute the (volume-weighted) average radiative temperature in the supernova ejecta (outside of the photosphere) and will print its value:

# %%
def average_temp(sim):
    t_rads = sim.simulation_state.t_radiative
    volumes = sim.simulation_state.volume
    avg = sum(t_rads*volumes) / sum(volumes)
    print(f"Average temperature for iteration {sim.iterations_executed}: {avg}")

# %% [markdown]
# Now we give the callback to `run_tardis`.  `run_tardis` offers the keyword argument `simulation_callbacks` which takes a list of lists containing the callback as well as any optional arguments you wish to include with your callback.  For this example our function requires no extra arguments and we only have a single callback, so we give `run_tardis` a 2D list containing the callback as its only element:

# %%
# We filter out warnings in this notebook
import warnings
warnings.filterwarnings('ignore')

from tardis import run_tardis
from tardis.io.atom_data import download_atom_data

# We download the atomic data needed to run the simulation
download_atom_data('kurucz_cd23_chianti_H_He_latest')

# We run the simulation with our callback
sim = run_tardis('tardis_example.yml', 
                 simulation_callbacks=[[average_temp]])
# Out:
# Iterations:          0/? [00:00<?, ?it/s]
# Packets:             0/? [00:00<?, ?it/s]
# Atomic Data kurucz_cd23_chianti_H_He_latest already exists in /home/runner/Downloads/tardis-data/kurucz_cd23_chianti_H_He_latest.h5. Will not download - override with force_download=True.
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='905d2d45-1cdc-4017-94a6-afdfad2d992c'>
#   <div id="a67b7dfd-c9ed-42d8-b6f5-8f3c0362b9d2" data-root-id="905d2d45-1cdc-4017-94a6-afdfad2d992c" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"6b2e531b-8517-4511-a494-e41ea75640a8":{"version":"3.6.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"905d2d45-1cdc-4017-94a6-afdfad2d992c"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"365f5298-1303-436f-bb10-5f7c54f84480","attributes":{"plot_id":"905d2d45-1cdc-4017-94a6-afdfad2d992c","comm_id":"3586070fc69f45c387aa82861bede22b","client_comm_id":"24c11de76c0442d09ab78e29d6e8119d"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","d ...
#   var render_items = [{"docid":"6b2e531b-8517-4511-a494-e41ea75640a8","roots":{"905d2d45-1cdc-4017-94a6-afdfad2d992c":"a67b7dfd-c9ed-42d8-b6f5-8f3c0362b9d2"},"root_ids":["905d2d45-1cdc-4017-94a6-afdfad2d992c"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.32.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.1/MathJax.js?config=TeX-MML-AM_SVG"></script>
# HTML(str)
# Column(height=10, scroll=True, sizing_mode='stretch_width', styles={'border': '1px solid #ddd...})
# HTML(str)
# Column(height=10, scroll=True, sizing_mode='stretch_width', styles={'border': '1px solid #ddd...})
# HTML(str)
# Column(height=10, scroll=True, sizing_mode='stretch_width', styles={'border': '1px solid #ddd...})
# TqdmHBox(children=(HTML(value='Iterations:', layout=Layout(width='6%')), FloatProgress(value=0.0, layout=Layou…
# TqdmHBox(children=(HTML(value='Packets:\u2007\u2007\u2007', layout=Layout(width='6%')), FloatProgress(value=0.…
# Average temperature for iteration 1: 10002.345335990905 K
# Average temperature for iteration 2: 10636.306724631839 K
# Average temperature for iteration 3: 10781.451660994117 K
# Average temperature for iteration 4: 10847.470538493748 K
# Average temperature for iteration 5: 10852.893010414327 K
# Average temperature for iteration 6: 10855.104475524438 K
# Average temperature for iteration 7: 10872.983731448345 K
# Average temperature for iteration 8: 10900.252453404333 K
# Average temperature for iteration 9: 10928.447457469569 K
# Average temperature for iteration 10: 10887.139946956373 K
# Average temperature for iteration 11: 10808.256295066209 K
# Average temperature for iteration 12: 10916.035502125074 K
# Average temperature for iteration 13: 10890.679856236407 K
# Average temperature for iteration 14: 10839.310459658938 K
# Average temperature for iteration 15: 10835.970184787593 K
# Average temperature for iteration 16: 10898.815372772322 K
# Average temperature for iteration 17: 10993.425063230141 K
# Average temperature for iteration 18: 10923.229603253854 K
# Average temperature for iteration 19: 10915.386068997337 K
# Average temperature for iteration 20: 10915.386068997337 K

# %% [markdown]
# ## Running Callbacks with Extra Arguments
#
# The callbacks provided to `run_tardis` can also take extra arguments. As an example, we'll make a callback that appends the number of monte carlo packets emitted by the supernova for each iteration to a list so we can plot the number of emitted packets for each iteration. We will also specify that we want this information for all but the last iteration, as more packets are used in the last iteration than are used in the other iterations. The callback will take a list we want to append to as an argument. We'll send both this new callback and our original `average_temp` callback to `run_tardis` as an example of using multiple callbacks at once:

# %%
def append_num_emitted_to_list(sim, lst):
    if sim.iterations_executed < sim.iterations:
        num_emitted_packets = len(sim.transport.transport_state.emitted_packet_nu)
        lst.append(num_emitted_packets)

# %% [markdown]
# In order to add our new callback, we just create another entry in our list of callbacks. Since `append_num_emitted_to_list` takes an extra argument, we will provide that argument in the inner list containing the callback:

# %%
# Initialize a list to store the number of emitted packets
num_emitted_list = []

# Make our list of callbacks
callbacks = [[average_temp], 
             [append_num_emitted_to_list, num_emitted_list]]

# Run the simulation with both of our callbacks
sim = run_tardis('tardis_example.yml', 
                 simulation_callbacks=callbacks)
# Out:
# HTML(str)
# Column(height=300, scroll=True, sizing_mode='stretch_width', styles={'border': '1px solid #ddd...})
#     [0] HTML(str, styles={'font-family': 'monospace...})
#     [1] HTML(str, styles={'font-family': 'monospace...})
#     [2] HTML(str, styles={'font-family': 'monospace...})
#     [3] HTML(str, styles={'font-family': 'monospace...})
#     [4] HTML(str, styles={'font-family': 'monospace...})
#     [5] HTML(str, styles={'font-family': 'monospace...})
#     [6] HTML(str, styles={'font-family': 'monospace...})
#     [7] HTML(str, styles={'font-family': 'monospace...})
#     [8] HTML(str, styles={'font-family': 'monospace...})
#     [9] HTML(str, styles={'font-family': 'monospace...})
#     [10] HTML(str, styles={'font-family': 'monospace...})
#     [11] HTML(str, styles={'font-family': 'monospace...})
#     [12] HTML(str, styles={'font-family': 'monospace...})
#     [13] HTML(str, styles={'font-family': 'monospace...})
#     [14] HTML(str, styles={'font-family': 'monospace...})
#     [15] HTML(str, styles={'font-family': 'monospace...})
#     [16] HTML(str, styles={'font-family': 'monospace...})
#     [17] HTML(str, styles={'font-family': 'monospace...})
#     [18] HTML(str, styles={'font-family': 'monospace...})
#     [19] HTML(str, styles={'font-family': 'monospace...})
#     [20] HTML(str, styles={'font-family': 'monospace...})
#     [21] HTML(str, styles={'font-family': 'monospace...})
#     [22] HTML(str, styles={'font-family': 'monospace...})
#     [23] HTML(str, styles={'font-family': 'monospace...})
#     [24] HTML(str, styles={'font-family': 'monospace...})
#     [25] HTML(str, styles={'font-family': 'monospace...})
#     [26] HTML(str, styles={'font-family': 'monospace...})
#     [27] HTML(str, styles={'font-family': 'monospace...})
#     [28] HTML(str, styles={'font-family': 'monospace...})
#     [29] HTML(str, styles={'font-family': 'monospace...})
#     [30] HTML(str, styles={'font-family': 'monospace...})
#     [31] HTML(str, styles={'font-family': 'monospace...})
#     [32] HTML(str, styles={'font-family': 'monospace...})
#     [33] HTML(str, styles={'font-family': 'monospace...})
#     [34] HTML(str, styles={'font-family': 'monospace...})
#     [35] HTML(str, styles={'font-family': 'monospace...})
#     [36] HTML(str, styles={'font-family': 'monospace...})
#     [37] HTML(str, styles={'font-family': 'monospace...})
#     [38] HTML(str, styles={'font-family': 'monospace...})
#     [39] HTML(str, styles={'font-family': 'monospace...})
#     [40] HTML(str, styles={'font-family': 'monospace...})
#     [41] HTML(str, styles={'font-family': 'monospace...})
#     [42] HTML(str, styles={'font-family': 'monospace...})
#     [43] HTML(str, styles={'font-family': 'monospace...})
#     [44] HTML(str, styles={'font-family': 'monospace...})
#     [45] HTML(str, styles={'font-family': 'monospace...})
#     [46] HTML(str, styles={'font-family': 'monospace...})
#     [47] HTML(str, styles={'font-family': 'monospace...})
#     [48] HTML(str, styles={'font-family': 'monospace...})
#     [49] HTML(str, styles={'font-family': 'monospace...})
#     [50] HTML(str, styles={'font-family': 'monospace...})
#     [51] HTML(str, styles={'font-family': 'monospace...})
#     [52] HTML(str, styles={'font-family': 'monospace...})
#     [53] HTML(str, styles={'font-family': 'monospace...})
#     [54] HTML(str, styles={'font-family': 'monospace...})
#     [55] HTML(str, styles={'font-family': 'monospace...})
#     [56] HTML(str, styles={'font-family': 'monospace...})
#     [57] HTML(str, styles={'font-family': 'monospace...})
#     [58] HTML(str, styles={'font-family': 'monospace...})
#     [59] HTML(str, styles={'font-family': 'monospace...})
#     [60] HTML(str, styles={'font-family': 'monospace...})
#     [61] HTML(str, styles={'font-family': 'monospace...})
#     [62] HTML(str, styles={'font-family': 'monospace...})
#     [63] HTML(str, styles={'font-family': 'monospace...})
#     [64] HTML(str, styles={'font-family': 'monospace...})
#     [65] HTML(str, styles={'font-family': 'monospace...})
#     [66] HTML(str, styles={'font-family': 'monospace...})
#     [67] HTML(str, styles={'font-family': 'monospace...})
#     [68] HTML(str, styles={'font-family': 'monospace...})
#     [69] HTML(str, styles={'font-family': 'monospace...})
#     [70] HTML(str, styles={'font-family': 'monospace...})
#     [71] HTML(str, styles={'font-family': 'monospace...})
#     [72] HTML(str, styles={'font-family': 'monospace...})
#     [73] HTML(str, styles={'font-family': 'monospace...})
#     [74] HTML(str, styles={'font-family': 'monospace...})
#     [75] HTML(str, styles={'font-family': 'monospace...})
#     [76] HTML(str, styles={'font-family': 'monospace...})
#     [77] HTML(str, styles={'font-family': 'monospace...})
#     [78] HTML(str, styles={'font-family': 'monospace...})
#     [79] HTML(str, styles={'font-family': 'monospace...})
#     [80] HTML(str, styles={'font-family': 'monospace...})
#     [81] HTML(str, styles={'font-family': 'monospace...})
#     [82] HTML(str, styles={'font-family': 'monospace...})
#     [83] HTML(str, styles={'font-family': 'monospace...})
#     [84] HTML(str, styles={'font-family': 'monospace...})
#     [85] HTML(str, styles={'font-family': 'monospace...})
#     [86] HTML(str, styles={'font-family': 'monospace...})
#     [87] HTML(str, styles={'font-family': 'monospace...})
#     [88] HTML(str, styles={'font-family': 'monospace...})
#     [89] HTML(str, styles={'font-family': 'monospace...})
#     [90] HTML(str, styles={'font-family': 'monospace...})
#     [91] HTML(str, styles={'font-family': 'monospace...})
#     [92] HTML(str, styles={'font-family': 'monospace...})
#     [93] HTML(str, styles={'font-family': 'monospace...})
#     [94] HTML(str, styles={'font-family': 'monospace...})
#     [95] HTML(str, styles={'font-family': 'monospace...})
#     [96] HTML(str, styles={'font-family': 'monospace...})
#     [97] HTML(str, styles={'font-family': 'monospace...})
#     [98] HTML(str, styles={'font-family': 'monospace...})
#     [99] HTML(str, styles={'font-family': 'monospace...})
#     [100] HTML(str, styles={'font-family': 'monospace...})
# HTML(str)
# Column(height=25, scroll=True, sizing_mode='stretch_width', styles={'border': '1px solid #ddd...})
#     [0] HTML(str, styles={'font-family': 'monospace...})
# HTML(str)
# Column(height=10, scroll=True, sizing_mode='stretch_width', styles={'border': '1px solid #ddd...})
# TqdmHBox(children=(HTML(value='Iterations:', layout=Layout(width='6%')), FloatProgress(value=0.0, layout=Layou…
# TqdmHBox(children=(HTML(value='Packets:\u2007\u2007\u2007', layout=Layout(width='6%')), FloatProgress(value=0.…
# Average temperature for iteration 1: 10002.345335990905 K
# Average temperature for iteration 2: 10636.306724631839 K
# Average temperature for iteration 3: 10781.451660994117 K
# Average temperature for iteration 4: 10847.470538493748 K
# Average temperature for iteration 5: 10852.893010414327 K
# Average temperature for iteration 6: 10855.104475524438 K
# Average temperature for iteration 7: 10872.983731448345 K
# Average temperature for iteration 8: 10900.252453404333 K
# Average temperature for iteration 9: 10928.447457469569 K
# Average temperature for iteration 10: 10887.139946956373 K
# Average temperature for iteration 11: 10808.256295066209 K
# Average temperature for iteration 12: 10916.035502125074 K
# Average temperature for iteration 13: 10890.679856236407 K
# Average temperature for iteration 14: 10839.310459658938 K
# Average temperature for iteration 15: 10835.970184787593 K
# Average temperature for iteration 16: 10898.815372772322 K
# Average temperature for iteration 17: 10993.425063230141 K
# Average temperature for iteration 18: 10923.229603253854 K
# Average temperature for iteration 19: 10915.386068997337 K
# Average temperature for iteration 20: 10915.386068997337 K

# %% [markdown]
# Now we can look at how many packets are emitted after each iteration:

# %%
import matplotlib.pyplot as plt

# Generate a list of each iteration number for the x-axis
iterations = list(range(1, len(num_emitted_list)+1))

# Plot the number of emitted packets
plt.plot(iterations, num_emitted_list)
plt.xlabel("Iteration")
plt.ylabel("Number of emitted packets")
# Out:
# Text(0, 0.5, 'Number of emitted packets')

# %% [markdown]
# ## Using Callbacks to Add New Functionality
#
# Callbacks can also add new functionality to the code. For example, we introduce one final callback `inc_packets` that will increase the number of packets in the following iteration by a number $N$ (which is an argument to the callback, in our example we shall use $N=1000$):

# %%
def inc_packets(sim, N):
    sim.no_of_packets += N

# %%
# Initialize a new list to store the number of emitted packets
num_emitted_list_new = []

# Make our new list of callbacks
callbacks = [[average_temp],
             [append_num_emitted_to_list, num_emitted_list_new], 
             [inc_packets, 1000]]

# Run the simulation with all three of our callbacks
sim = run_tardis('tardis_example.yml', 
                 simulation_callbacks=callbacks)
# Out:
# HTML(str)
# Column(height=300, scroll=True, sizing_mode='stretch_width', styles={'border': '1px solid #ddd...})
#     [0] HTML(str, styles={'font-family': 'monospace...})
#     [1] HTML(str, styles={'font-family': 'monospace...})
#     [2] HTML(str, styles={'font-family': 'monospace...})
#     [3] HTML(str, styles={'font-family': 'monospace...})
#     [4] HTML(str, styles={'font-family': 'monospace...})
#     [5] HTML(str, styles={'font-family': 'monospace...})
#     [6] HTML(str, styles={'font-family': 'monospace...})
#     [7] HTML(str, styles={'font-family': 'monospace...})
#     [8] HTML(str, styles={'font-family': 'monospace...})
#     [9] HTML(str, styles={'font-family': 'monospace...})
#     [10] HTML(str, styles={'font-family': 'monospace...})
#     [11] HTML(str, styles={'font-family': 'monospace...})
#     [12] HTML(str, styles={'font-family': 'monospace...})
#     [13] HTML(str, styles={'font-family': 'monospace...})
#     [14] HTML(str, styles={'font-family': 'monospace...})
#     [15] HTML(str, styles={'font-family': 'monospace...})
#     [16] HTML(str, styles={'font-family': 'monospace...})
#     [17] HTML(str, styles={'font-family': 'monospace...})
#     [18] HTML(str, styles={'font-family': 'monospace...})
#     [19] HTML(str, styles={'font-family': 'monospace...})
#     [20] HTML(str, styles={'font-family': 'monospace...})
#     [21] HTML(str, styles={'font-family': 'monospace...})
#     [22] HTML(str, styles={'font-family': 'monospace...})
#     [23] HTML(str, styles={'font-family': 'monospace...})
#     [24] HTML(str, styles={'font-family': 'monospace...})
#     [25] HTML(str, styles={'font-family': 'monospace...})
#     [26] HTML(str, styles={'font-family': 'monospace...})
#     [27] HTML(str, styles={'font-family': 'monospace...})
#     [28] HTML(str, styles={'font-family': 'monospace...})
#     [29] HTML(str, styles={'font-family': 'monospace...})
#     [30] HTML(str, styles={'font-family': 'monospace...})
#     [31] HTML(str, styles={'font-family': 'monospace...})
#     [32] HTML(str, styles={'font-family': 'monospace...})
#     [33] HTML(str, styles={'font-family': 'monospace...})
#     [34] HTML(str, styles={'font-family': 'monospace...})
#     [35] HTML(str, styles={'font-family': 'monospace...})
#     [36] HTML(str, styles={'font-family': 'monospace...})
#     [37] HTML(str, styles={'font-family': 'monospace...})
#     [38] HTML(str, styles={'font-family': 'monospace...})
#     [39] HTML(str, styles={'font-family': 'monospace...})
#     [40] HTML(str, styles={'font-family': 'monospace...})
#     [41] HTML(str, styles={'font-family': 'monospace...})
#     [42] HTML(str, styles={'font-family': 'monospace...})
#     [43] HTML(str, styles={'font-family': 'monospace...})
#     [44] HTML(str, styles={'font-family': 'monospace...})
#     [45] HTML(str, styles={'font-family': 'monospace...})
#     [46] HTML(str, styles={'font-family': 'monospace...})
#     [47] HTML(str, styles={'font-family': 'monospace...})
#     [48] HTML(str, styles={'font-family': 'monospace...})
#     [49] HTML(str, styles={'font-family': 'monospace...})
#     [50] HTML(str, styles={'font-family': 'monospace...})
#     [51] HTML(str, styles={'font-family': 'monospace...})
#     [52] HTML(str, styles={'font-family': 'monospace...})
#     [53] HTML(str, styles={'font-family': 'monospace...})
#     [54] HTML(str, styles={'font-family': 'monospace...})
#     [55] HTML(str, styles={'font-family': 'monospace...})
#     [56] HTML(str, styles={'font-family': 'monospace...})
#     [57] HTML(str, styles={'font-family': 'monospace...})
#     [58] HTML(str, styles={'font-family': 'monospace...})
#     [59] HTML(str, styles={'font-family': 'monospace...})
#     [60] HTML(str, styles={'font-family': 'monospace...})
#     [61] HTML(str, styles={'font-family': 'monospace...})
#     [62] HTML(str, styles={'font-family': 'monospace...})
#     [63] HTML(str, styles={'font-family': 'monospace...})
#     [64] HTML(str, styles={'font-family': 'monospace...})
#     [65] HTML(str, styles={'font-family': 'monospace...})
#     [66] HTML(str, styles={'font-family': 'monospace...})
#     [67] HTML(str, styles={'font-family': 'monospace...})
#     [68] HTML(str, styles={'font-family': 'monospace...})
#     [69] HTML(str, styles={'font-family': 'monospace...})
#     [70] HTML(str, styles={'font-family': 'monospace...})
#     [71] HTML(str, styles={'font-family': 'monospace...})
#     [72] HTML(str, styles={'font-family': 'monospace...})
#     [73] HTML(str, styles={'font-family': 'monospace...})
#     [74] HTML(str, styles={'font-family': 'monospace...})
#     [75] HTML(str, styles={'font-family': 'monospace...})
#     [76] HTML(str, styles={'font-family': 'monospace...})
#     [77] HTML(str, styles={'font-family': 'monospace...})
#     [78] HTML(str, styles={'font-family': 'monospace...})
#     [79] HTML(str, styles={'font-family': 'monospace...})
#     [80] HTML(str, styles={'font-family': 'monospace...})
#     [81] HTML(str, styles={'font-family': 'monospace...})
#     [82] HTML(str, styles={'font-family': 'monospace...})
#     [83] HTML(str, styles={'font-family': 'monospace...})
#     [84] HTML(str, styles={'font-family': 'monospace...})
#     [85] HTML(str, styles={'font-family': 'monospace...})
#     [86] HTML(str, styles={'font-family': 'monospace...})
#     [87] HTML(str, styles={'font-family': 'monospace...})
#     [88] HTML(str, styles={'font-family': 'monospace...})
#     [89] HTML(str, styles={'font-family': 'monospace...})
#     [90] HTML(str, styles={'font-family': 'monospace...})
#     [91] HTML(str, styles={'font-family': 'monospace...})
#     [92] HTML(str, styles={'font-family': 'monospace...})
#     [93] HTML(str, styles={'font-family': 'monospace...})
#     [94] HTML(str, styles={'font-family': 'monospace...})
#     [95] HTML(str, styles={'font-family': 'monospace...})
#     [96] HTML(str, styles={'font-family': 'monospace...})
#     [97] HTML(str, styles={'font-family': 'monospace...})
#     [98] HTML(str, styles={'font-family': 'monospace...})
#     [99] HTML(str, styles={'font-family': 'monospace...})
#     [100] HTML(str, styles={'font-family': 'monospace...})
#     [101] HTML(str, styles={'font-family': 'monospace...})
#     [102] HTML(str, styles={'font-family': 'monospace...})
#     [103] HTML(str, styles={'font-family': 'monospace...})
#     [104] HTML(str, styles={'font-family': 'monospace...})
#     [105] HTML(str, styles={'font-family': 'monospace...})
#     [106] HTML(str, styles={'font-family': 'monospace...})
#     [107] HTML(str, styles={'font-family': 'monospace...})
#     [108] HTML(str, styles={'font-family': 'monospace...})
#     [109] HTML(str, styles={'font-family': 'monospace...})
#     [110] HTML(str, styles={'font-family': 'monospace...})
#     [111] HTML(str, styles={'font-family': 'monospace...})
#     [112] HTML(str, styles={'font-family': 'monospace...})
#     [113] HTML(str, styles={'font-family': 'monospace...})
#     [114] HTML(str, styles={'font-family': 'monospace...})
#     [115] HTML(str, styles={'font-family': 'monospace...})
#     [116] HTML(str, styles={'font-family': 'monospace...})
#     [117] HTML(str, styles={'font-family': 'monospace...})
#     [118] HTML(str, styles={'font-family': 'monospace...})
#     [119] HTML(str, styles={'font-family': 'monospace...})
#     [120] HTML(str, styles={'font-family': 'monospace...})
#     [121] HTML(str, styles={'font-family': 'monospace...})
#     [122] HTML(str, styles={'font-family': 'monospace...})
#     [123] HTML(str, styles={'font-family': 'monospace...})
#     [124] HTML(str, styles={'font-family': 'monospace...})
#     [125] HTML(str, styles={'font-family': 'monospace...})
#     [126] HTML(str, styles={'font-family': 'monospace...})
#     [127] HTML(str, styles={'font-family': 'monospace...})
#     [128] HTML(str, styles={'font-family': 'monospace...})
#     [129] HTML(str, styles={'font-family': 'monospace...})
#     [130] HTML(str, styles={'font-family': 'monospace...})
#     [131] HTML(str, styles={'font-family': 'monospace...})
#     [132] HTML(str, styles={'font-family': 'monospace...})
#     [133] HTML(str, styles={'font-family': 'monospace...})
#     [134] HTML(str, styles={'font-family': 'monospace...})
#     [135] HTML(str, styles={'font-family': 'monospace...})
#     [136] HTML(str, styles={'font-family': 'monospace...})
#     [137] HTML(str, styles={'font-family': 'monospace...})
#     [138] HTML(str, styles={'font-family': 'monospace...})
#     [139] HTML(str, styles={'font-family': 'monospace...})
#     [140] HTML(str, styles={'font-family': 'monospace...})
#     [141] HTML(str, styles={'font-family': 'monospace...})
#     [142] HTML(str, styles={'font-family': 'monospace...})
#     [143] HTML(str, styles={'font-family': 'monospace...})
#     [144] HTML(str, styles={'font-family': 'monospace...})
#     [145] HTML(str, styles={'font-family': 'monospace...})
#     [146] HTML(str, styles={'font-family': 'monospace...})
#     [147] HTML(str, styles={'font-family': 'monospace...})
#     [148] HTML(str, styles={'font-family': 'monospace...})
#     [149] HTML(str, styles={'font-family': 'monospace...})
#     [150] HTML(str, styles={'font-family': 'monospace...})
#     [151] HTML(str, styles={'font-family': 'monospace...})
#     [152] HTML(str, styles={'font-family': 'monospace...})
#     [153] HTML(str, styles={'font-family': 'monospace...})
#     [154] HTML(str, styles={'font-family': 'monospace...})
#     [155] HTML(str, styles={'font-family': 'monospace...})
#     [156] HTML(str, styles={'font-family': 'monospace...})
#     [157] HTML(str, styles={'font-family': 'monospace...})
#     [158] HTML(str, styles={'font-family': 'monospace...})
#     [159] HTML(str, styles={'font-family': 'monospace...})
#     [160] HTML(str, styles={'font-family': 'monospace...})
#     [161] HTML(str, styles={'font-family': 'monospace...})
#     [162] HTML(str, styles={'font-family': 'monospace...})
#     [163] HTML(str, styles={'font-family': 'monospace...})
#     [164] HTML(str, styles={'font-family': 'monospace...})
#     [165] HTML(str, styles={'font-family': 'monospace...})
#     [166] HTML(str, styles={'font-family': 'monospace...})
#     [167] HTML(str, styles={'font-family': 'monospace...})
#     [168] HTML(str, styles={'font-family': 'monospace...})
#     [169] HTML(str, styles={'font-family': 'monospace...})
#     [170] HTML(str, styles={'font-family': 'monospace...})
#     [171] HTML(str, styles={'font-family': 'monospace...})
#     [172] HTML(str, styles={'font-family': 'monospace...})
#     [173] HTML(str, styles={'font-family': 'monospace...})
#     [174] HTML(str, styles={'font-family': 'monospace...})
#     [175] HTML(str, styles={'font-family': 'monospace...})
#     [176] HTML(str, styles={'font-family': 'monospace...})
#     [177] HTML(str, styles={'font-family': 'monospace...})
#     [178] HTML(str, styles={'font-family': 'monospace...})
#     [179] HTML(str, styles={'font-family': 'monospace...})
#     [180] HTML(str, styles={'font-family': 'monospace...})
#     [181] HTML(str, styles={'font-family': 'monospace...})
#     [182] HTML(str, styles={'font-family': 'monospace...})
#     [183] HTML(str, styles={'font-family': 'monospace...})
#     [184] HTML(str, styles={'font-family': 'monospace...})
#     [185] HTML(str, styles={'font-family': 'monospace...})
#     [186] HTML(str, styles={'font-family': 'monospace...})
#     [187] HTML(str, styles={'font-family': 'monospace...})
#     [188] HTML(str, styles={'font-family': 'monospace...})
#     [189] HTML(str, styles={'font-family': 'monospace...})
#     [190] HTML(str, styles={'font-family': 'monospace...})
#     [191] HTML(str, styles={'font-family': 'monospace...})
#     [192] HTML(str, styles={'font-family': 'monospace...})
#     [193] HTML(str, styles={'font-family': 'monospace...})
#     [194] HTML(str, styles={'font-family': 'monospace...})
#     [195] HTML(str, styles={'font-family': 'monospace...})
#     [196] HTML(str, styles={'font-family': 'monospace...})
#     [197] HTML(str, styles={'font-family': 'monospace...})
#     [198] HTML(str, styles={'font-family': 'monospace...})
#     [199] HTML(str, styles={'font-family': 'monospace...})
#     [200] HTML(str, styles={'font-family': 'monospace...})
#     [201] HTML(str, styles={'font-family': 'monospace...})
# HTML(str)
# Column(height=50, scroll=True, sizing_mode='stretch_width', styles={'border': '1px solid #ddd...})
#     [0] HTML(str, styles={'font-family': 'monospace...})
#     [1] HTML(str, styles={'font-family': 'monospace...})
# HTML(str)
# Column(height=10, scroll=True, sizing_mode='stretch_width', styles={'border': '1px solid #ddd...})
# TqdmHBox(children=(HTML(value='Iterations:', layout=Layout(width='6%')), FloatProgress(value=0.0, layout=Layou…
# TqdmHBox(children=(HTML(value='Packets:\u2007\u2007\u2007', layout=Layout(width='6%')), FloatProgress(value=0.…
# Average temperature for iteration 1: 10002.345335990905 K
# Average temperature for iteration 2: 10613.908754846558 K
# Average temperature for iteration 3: 10850.348012607232 K
# Average temperature for iteration 4: 10887.571829540853 K
# Average temperature for iteration 5: 10830.30318618678 K
# Average temperature for iteration 6: 10858.234351239738 K
# Average temperature for iteration 7: 10792.481079535482 K
# Average temperature for iteration 8: 10838.693927807315 K
# Average temperature for iteration 9: 10947.325467890487 K
# Average temperature for iteration 10: 10904.884829767207 K
# Average temperature for iteration 11: 10909.70977691611 K
# Average temperature for iteration 12: 10936.034767331808 K
# Average temperature for iteration 13: 10914.993081485425 K
# Average temperature for iteration 14: 10926.52320767812 K
# Average temperature for iteration 15: 10919.420818412638 K
# Average temperature for iteration 16: 10898.993427208812 K
# Average temperature for iteration 17: 10868.841791849643 K
# Average temperature for iteration 18: 10868.404619085652 K
# Average temperature for iteration 19: 10935.815023903202 K
# Average temperature for iteration 20: 10935.815023903202 K

# %% [markdown]
# Now, let's see how this affected our plot for packets emitted in each iteration:

# %%
plt.plot(iterations, num_emitted_list_new)
plt.xlabel("Iteration")
plt.ylabel("Number of emitted packets")
# Out:
# Text(0, 0.5, 'Number of emitted packets')

# %% [markdown]
# As expected, the number of packets emitted will keep on increasing as 1000 more packets are run each iteration.
