# %% [markdown]
# # **Welcome to the GSoC 2020 TARDIS Challenge!**

# %% [markdown]
# This challenge aims to inform potential applicants about the science mission of the TARDIS Collaboration. It is also an opportunity to demostrate your creativity and resourcefulness while solving problems.

# %% [markdown]
# **Let's begin!**

# %% [markdown]
# First we need to install some dependencies and download some data. Please run each cell in order by pressing shift-enter.

# %%
# !pip install numpy==1.15.4
#You might be asked to restart runtime. Please do so.
# Out:
# Collecting numpy==1.15.4
#   Using cached numpy-1.15.4.zip (4.5 MB)
# Building wheels for collected packages: numpy
#   Building wheel for numpy (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /home/jayant/anaconda3/envs/tardis/bin/python3.8 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-qnwwzi3d/numpy_3810a2a7a2e1465b9ca7891a3217754a/setup.py'"'"'; __file__='"'"'/tmp/pip-install-qnwwzi3d/numpy_3810a2a7a2e1465b9ca7891a3217754a/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-907rg5er
#        cwd: /tmp/pip-install-qnwwzi3d/numpy_3810a2a7a2e1465b9ca7891a3217754a/
#   Complete output (2941 lines):
#   Running from numpy source directory.
#   /tmp/pip-install-qnwwzi3d/numpy_3810a2a7a2e1465b9ca7891a3217754a/numpy/distutils/misc_util.py:477: SyntaxWarning: "is" with a literal. Did you mean "=="?
#     return is_string(s) and ('*' in s or '?' is s)
#   blas_opt_info:
#   blas_mkl_info:
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmptf4d76l8/tmp
#   creating /tmp/tmptf4d76l8/tmp/tmptf4d76l8
#   compile options: '-MMD -MF /tmp/tmptf4d76l8/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmptf4d76l8/file.c
#     libraries mkl_rt not found in ['/home/jayant/anaconda3/envs/tardis/lib', '/usr/local/lib', '/usr/lib64', '/usr/lib', '/usr/lib/']
#     NOT AVAILABLE
#
#   blis_info:
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmppbjyl0eh/tmp
#   creating /tmp/tmppbjyl0eh/tmp/tmppbjyl0eh
#   compile options: '-MMD -MF /tmp/tmppbjyl0eh/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmppbjyl0eh/file.c
#     libraries blis not found in ['/home/jayant/anaconda3/envs/tardis/lib', '/usr/local/lib', '/usr/lib64', '/usr/lib', '/usr/lib/']
#     NOT AVAILABLE
#
#   openblas_info:
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmpe_n3w5mb/tmp
#   creating /tmp/tmpe_n3w5mb/tmp/tmpe_n3w5mb
#   compile options: '-MMD -MF /tmp/tmpe_n3w5mb/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmpe_n3w5mb/file.c
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmpu54ewtrc/tmp
#   creating /tmp/tmpu54ewtrc/tmp/tmpu54ewtrc
#   compile options: '-MMD -MF /tmp/tmpu54ewtrc/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmpu54ewtrc/file.c
#     libraries openblas not found in ['/home/jayant/anaconda3/envs/tardis/lib', '/usr/local/lib', '/usr/lib64', '/usr/lib', '/usr/lib/']
#     NOT AVAILABLE
#
#   atlas_3_10_blas_threads_info:
#   Setting PTATLAS=ATLAS
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmprfat36hs/tmp
#   creating /tmp/tmprfat36hs/tmp/tmprfat36hs
#   compile options: '-MMD -MF /tmp/tmprfat36hs/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmprfat36hs/file.c
#     libraries tatlas not found in ['/home/jayant/anaconda3/envs/tardis/lib', '/usr/local/lib', '/usr/lib64', '/usr/lib', '/usr/lib/']
#     NOT AVAILABLE
#
#   atlas_3_10_blas_info:
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmpzjdrj979/tmp
#   creating /tmp/tmpzjdrj979/tmp/tmpzjdrj979
#   compile options: '-MMD -MF /tmp/tmpzjdrj979/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmpzjdrj979/file.c
#     libraries satlas not found in ['/home/jayant/anaconda3/envs/tardis/lib', '/usr/local/lib', '/usr/lib64', '/usr/lib', '/usr/lib/']
#     NOT AVAILABLE
#
#   atlas_blas_threads_info:
#   Setting PTATLAS=ATLAS
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmpmljwnmlo/tmp
#   creating /tmp/tmpmljwnmlo/tmp/tmpmljwnmlo
#   compile options: '-MMD -MF /tmp/tmpmljwnmlo/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmpmljwnmlo/file.c
#     libraries ptf77blas,ptcblas,atlas not found in ['/home/jayant/anaconda3/envs/tardis/lib', '/usr/local/lib', '/usr/lib64', '/usr/lib', '/usr/lib/']
#     NOT AVAILABLE
#
#   atlas_blas_info:
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmpokqh7ay8/tmp
#   creating /tmp/tmpokqh7ay8/tmp/tmpokqh7ay8
#   compile options: '-MMD -MF /tmp/tmpokqh7ay8/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmpokqh7ay8/file.c
#     libraries f77blas,cblas,atlas not found in ['/home/jayant/anaconda3/envs/tardis/lib', '/usr/local/lib', '/usr/lib64', '/usr/lib', '/usr/lib/']
#     NOT AVAILABLE
#
#   accelerate_info:
#     NOT AVAILABLE
#
#   /tmp/pip-install-qnwwzi3d/numpy_3810a2a7a2e1465b9ca7891a3217754a/numpy/distutils/system_info.py:625: UserWarning:
#       Atlas (http://math-atlas.sourceforge.net/) libraries not found.
#       Directories to search for the libraries can be specified in the
#       numpy/distutils/site.cfg file (section [atlas]) or by setting
#       the ATLAS environment variable.
#     self.calc_info()
#   blas_info:
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmp1mxu1fzw/tmp
#   creating /tmp/tmp1mxu1fzw/tmp/tmp1mxu1fzw
#   compile options: '-MMD -MF /tmp/tmp1mxu1fzw/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmp1mxu1fzw/file.c
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmpr2263j2w/tmp
#   creating /tmp/tmpr2263j2w/tmp/tmpr2263j2w
#   compile options: '-MMD -MF /tmp/tmpr2263j2w/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmpr2263j2w/file.c
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmpn7nw74df/tmp
#   creating /tmp/tmpn7nw74df/tmp/tmpn7nw74df
#   compile options: '-I/usr/local/include -I/usr/include -I/home/jayant/anaconda3/envs/tardis/include -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmpn7nw74df/source.c
#   /tmp/tmpn7nw74df/source.c:1:10: fatal error: cblas.h: No such file or directory
#       1 | #include <cblas.h>
#         |          ^~~~~~~~~
#   compilation terminated.
#   /tmp/tmpn7nw74df/source.c:1:10: fatal error: cblas.h: No such file or directory
#       1 | #include <cblas.h>
#         |          ^~~~~~~~~
#   compilation terminated.
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmpb9zgskuj/tmp
#   creating /tmp/tmpb9zgskuj/tmp/tmpb9zgskuj
#   compile options: '-MMD -MF /tmp/tmpb9zgskuj/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmpb9zgskuj/file.c
#     FOUND:
#       libraries = ['blas', 'blas']
#       library_dirs = ['/home/jayant/anaconda3/envs/tardis/lib']
#       include_dirs = ['/usr/local/include', '/usr/include', '/home/jayant/anaconda3/envs/tardis/include']
#
#     FOUND:
#       define_macros = [('NO_ATLAS_INFO', 1)]
#       libraries = ['blas', 'blas']
#       library_dirs = ['/home/jayant/anaconda3/envs/tardis/lib']
#       include_dirs = ['/usr/local/include', '/usr/include', '/home/jayant/anaconda3/envs/tardis/include']
#
#   /bin/sh: 1: svnversion: not found
#   non-existing path in 'numpy/distutils': 'site.cfg'
#   /bin/sh: 1: svnversion: not found
#   F2PY Version 2
#   lapack_opt_info:
#   lapack_mkl_info:
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmpexvw4ozf/tmp
#   creating /tmp/tmpexvw4ozf/tmp/tmpexvw4ozf
#   compile options: '-MMD -MF /tmp/tmpexvw4ozf/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmpexvw4ozf/file.c
#     libraries mkl_rt not found in ['/home/jayant/anaconda3/envs/tardis/lib', '/usr/local/lib', '/usr/lib64', '/usr/lib', '/usr/lib/']
#     NOT AVAILABLE
#
#   openblas_lapack_info:
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmp_hgli1di/tmp
#   creating /tmp/tmp_hgli1di/tmp/tmp_hgli1di
#   compile options: '-MMD -MF /tmp/tmp_hgli1di/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmp_hgli1di/file.c
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmpgi_vp3pr/tmp
#   creating /tmp/tmpgi_vp3pr/tmp/tmpgi_vp3pr
#   compile options: '-MMD -MF /tmp/tmpgi_vp3pr/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmpgi_vp3pr/file.c
#     libraries openblas not found in ['/home/jayant/anaconda3/envs/tardis/lib', '/usr/local/lib', '/usr/lib64', '/usr/lib', '/usr/lib/']
#     NOT AVAILABLE
#
#   openblas_clapack_info:
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmpgyl0ubsi/tmp
#   creating /tmp/tmpgyl0ubsi/tmp/tmpgyl0ubsi
#   compile options: '-MMD -MF /tmp/tmpgyl0ubsi/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmpgyl0ubsi/file.c
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmpl8igdydy/tmp
#   creating /tmp/tmpl8igdydy/tmp/tmpl8igdydy
#   compile options: '-MMD -MF /tmp/tmpl8igdydy/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmpl8igdydy/file.c
#     libraries openblas,lapack not found in ['/home/jayant/anaconda3/envs/tardis/lib', '/usr/local/lib', '/usr/lib64', '/usr/lib', '/usr/lib/']
#     NOT AVAILABLE
#
#   atlas_3_10_threads_info:
#   Setting PTATLAS=ATLAS
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmpwuxo562s/tmp
#   creating /tmp/tmpwuxo562s/tmp/tmpwuxo562s
#   compile options: '-MMD -MF /tmp/tmpwuxo562s/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmpwuxo562s/file.c
#     libraries tatlas,tatlas not found in /home/jayant/anaconda3/envs/tardis/lib
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmp6_a31ur5/tmp
#   creating /tmp/tmp6_a31ur5/tmp/tmp6_a31ur5
#   compile options: '-MMD -MF /tmp/tmp6_a31ur5/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmp6_a31ur5/file.c
#     libraries lapack_atlas not found in /home/jayant/anaconda3/envs/tardis/lib
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmplg0rq_hr/tmp
#   creating /tmp/tmplg0rq_hr/tmp/tmplg0rq_hr
#   compile options: '-MMD -MF /tmp/tmplg0rq_hr/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmplg0rq_hr/file.c
#     libraries tatlas,tatlas not found in /usr/local/lib
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmp5063d3ge/tmp
#   creating /tmp/tmp5063d3ge/tmp/tmp5063d3ge
#   compile options: '-MMD -MF /tmp/tmp5063d3ge/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmp5063d3ge/file.c
#     libraries lapack_atlas not found in /usr/local/lib
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmppz7mns_t/tmp
#   creating /tmp/tmppz7mns_t/tmp/tmppz7mns_t
#   compile options: '-MMD -MF /tmp/tmppz7mns_t/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmppz7mns_t/file.c
#     libraries tatlas,tatlas not found in /usr/lib64
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmptor6y5vg/tmp
#   creating /tmp/tmptor6y5vg/tmp/tmptor6y5vg
#   compile options: '-MMD -MF /tmp/tmptor6y5vg/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmptor6y5vg/file.c
#     libraries lapack_atlas not found in /usr/lib64
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmp7sm0l3ni/tmp
#   creating /tmp/tmp7sm0l3ni/tmp/tmp7sm0l3ni
#   compile options: '-MMD -MF /tmp/tmp7sm0l3ni/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmp7sm0l3ni/file.c
#     libraries tatlas,tatlas not found in /usr/lib
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmpsxdlrtgv/tmp
#   creating /tmp/tmpsxdlrtgv/tmp/tmpsxdlrtgv
#   compile options: '-MMD -MF /tmp/tmpsxdlrtgv/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmpsxdlrtgv/file.c
#     libraries lapack_atlas not found in /usr/lib
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmpgklspssi/tmp
#   creating /tmp/tmpgklspssi/tmp/tmpgklspssi
#   compile options: '-MMD -MF /tmp/tmpgklspssi/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmpgklspssi/file.c
#     libraries tatlas,tatlas not found in /usr/lib/
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmph95vlc38/tmp
#   creating /tmp/tmph95vlc38/tmp/tmph95vlc38
#   compile options: '-MMD -MF /tmp/tmph95vlc38/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmph95vlc38/file.c
#     libraries lapack_atlas not found in /usr/lib/
#   <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#     NOT AVAILABLE
#
#   atlas_3_10_info:
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmpjo1fiurr/tmp
#   creating /tmp/tmpjo1fiurr/tmp/tmpjo1fiurr
#   compile options: '-MMD -MF /tmp/tmpjo1fiurr/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmpjo1fiurr/file.c
#     libraries satlas,satlas not found in /home/jayant/anaconda3/envs/tardis/lib
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmpyzaoejyx/tmp
#   creating /tmp/tmpyzaoejyx/tmp/tmpyzaoejyx
#   compile options: '-MMD -MF /tmp/tmpyzaoejyx/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmpyzaoejyx/file.c
#     libraries lapack_atlas not found in /home/jayant/anaconda3/envs/tardis/lib
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmp3_mnavhk/tmp
#   creating /tmp/tmp3_mnavhk/tmp/tmp3_mnavhk
#   compile options: '-MMD -MF /tmp/tmp3_mnavhk/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmp3_mnavhk/file.c
#     libraries satlas,satlas not found in /usr/local/lib
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmpaaefm174/tmp
#   creating /tmp/tmpaaefm174/tmp/tmpaaefm174
#   compile options: '-MMD -MF /tmp/tmpaaefm174/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmpaaefm174/file.c
#     libraries lapack_atlas not found in /usr/local/lib
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmpfo50puvz/tmp
#   creating /tmp/tmpfo50puvz/tmp/tmpfo50puvz
#   compile options: '-MMD -MF /tmp/tmpfo50puvz/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmpfo50puvz/file.c
#     libraries satlas,satlas not found in /usr/lib64
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmp4xvmcazt/tmp
#   creating /tmp/tmp4xvmcazt/tmp/tmp4xvmcazt
#   compile options: '-MMD -MF /tmp/tmp4xvmcazt/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmp4xvmcazt/file.c
#     libraries lapack_atlas not found in /usr/lib64
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmpn_x5i66m/tmp
#   creating /tmp/tmpn_x5i66m/tmp/tmpn_x5i66m
#   compile options: '-MMD -MF /tmp/tmpn_x5i66m/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmpn_x5i66m/file.c
#     libraries satlas,satlas not found in /usr/lib
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmplxgb92uu/tmp
#   creating /tmp/tmplxgb92uu/tmp/tmplxgb92uu
#   compile options: '-MMD -MF /tmp/tmplxgb92uu/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmplxgb92uu/file.c
#     libraries lapack_atlas not found in /usr/lib
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmp870qosky/tmp
#   creating /tmp/tmp870qosky/tmp/tmp870qosky
#   compile options: '-MMD -MF /tmp/tmp870qosky/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmp870qosky/file.c
#     libraries satlas,satlas not found in /usr/lib/
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmpo1io4dz9/tmp
#   creating /tmp/tmpo1io4dz9/tmp/tmpo1io4dz9
#   compile options: '-MMD -MF /tmp/tmpo1io4dz9/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmpo1io4dz9/file.c
#     libraries lapack_atlas not found in /usr/lib/
#   <class 'numpy.distutils.system_info.atlas_3_10_info'>
#     NOT AVAILABLE
#
#   atlas_threads_info:
#   Setting PTATLAS=ATLAS
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmpzrktrg8j/tmp
#   creating /tmp/tmpzrktrg8j/tmp/tmpzrktrg8j
#   compile options: '-MMD -MF /tmp/tmpzrktrg8j/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmpzrktrg8j/file.c
#     libraries ptf77blas,ptcblas,atlas not found in /home/jayant/anaconda3/envs/tardis/lib
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmpw215ssbg/tmp
#   creating /tmp/tmpw215ssbg/tmp/tmpw215ssbg
#   compile options: '-MMD -MF /tmp/tmpw215ssbg/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmpw215ssbg/file.c
#     libraries lapack_atlas not found in /home/jayant/anaconda3/envs/tardis/lib
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmplsip40zu/tmp
#   creating /tmp/tmplsip40zu/tmp/tmplsip40zu
#   compile options: '-MMD -MF /tmp/tmplsip40zu/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmplsip40zu/file.c
#     libraries ptf77blas,ptcblas,atlas not found in /usr/local/lib
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmp6y_xs_di/tmp
#   creating /tmp/tmp6y_xs_di/tmp/tmp6y_xs_di
#   compile options: '-MMD -MF /tmp/tmp6y_xs_di/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmp6y_xs_di/file.c
#     libraries lapack_atlas not found in /usr/local/lib
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmp47qwx2m6/tmp
#   creating /tmp/tmp47qwx2m6/tmp/tmp47qwx2m6
#   compile options: '-MMD -MF /tmp/tmp47qwx2m6/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmp47qwx2m6/file.c
#     libraries ptf77blas,ptcblas,atlas not found in /usr/lib64
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmp461nj6ds/tmp
#   creating /tmp/tmp461nj6ds/tmp/tmp461nj6ds
#   compile options: '-MMD -MF /tmp/tmp461nj6ds/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmp461nj6ds/file.c
#     libraries lapack_atlas not found in /usr/lib64
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmphjfr2tjb/tmp
#   creating /tmp/tmphjfr2tjb/tmp/tmphjfr2tjb
#   compile options: '-MMD -MF /tmp/tmphjfr2tjb/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmphjfr2tjb/file.c
#     libraries ptf77blas,ptcblas,atlas not found in /usr/lib
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmp3qh9csh1/tmp
#   creating /tmp/tmp3qh9csh1/tmp/tmp3qh9csh1
#   compile options: '-MMD -MF /tmp/tmp3qh9csh1/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmp3qh9csh1/file.c
#     libraries lapack_atlas not found in /usr/lib
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmppzmpmf01/tmp
#   creating /tmp/tmppzmpmf01/tmp/tmppzmpmf01
#   compile options: '-MMD -MF /tmp/tmppzmpmf01/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmppzmpmf01/file.c
#     libraries ptf77blas,ptcblas,atlas not found in /usr/lib/
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmplrnsnak7/tmp
#   creating /tmp/tmplrnsnak7/tmp/tmplrnsnak7
#   compile options: '-MMD -MF /tmp/tmplrnsnak7/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmplrnsnak7/file.c
#     libraries lapack_atlas not found in /usr/lib/
#   <class 'numpy.distutils.system_info.atlas_threads_info'>
#     NOT AVAILABLE
#
#   atlas_info:
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmpwkbjz5d5/tmp
#   creating /tmp/tmpwkbjz5d5/tmp/tmpwkbjz5d5
#   compile options: '-MMD -MF /tmp/tmpwkbjz5d5/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmpwkbjz5d5/file.c
#     libraries f77blas,cblas,atlas not found in /home/jayant/anaconda3/envs/tardis/lib
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmpqs6u6544/tmp
#   creating /tmp/tmpqs6u6544/tmp/tmpqs6u6544
#   compile options: '-MMD -MF /tmp/tmpqs6u6544/file.c.d -c'
#   x86_64-conda-linux-gnu-cc: /tmp/tmpqs6u6544/file.c
#     libraries lapack_atlas not found in /home/jayant/anaconda3/envs/tardis/lib
#   customize UnixCCompiler
#   C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#   creating /tmp/tmpazkf41w5/tmp
#   creating /tmp/tmpazkf41w5/tmp/tmpazkf41w5
# ...
#
#     compile options: '-Inumpy/core/src/private -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/home/jayant/anaconda3/envs/tardis/include/python3.8 -c'
#     x86_64-conda-linux-gnu-cc: _configtest.c
#     /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc _configtest.o -o _configtest
#     success!
#     removing: _configtest.c _configtest.o _configtest.o.d _configtest
#     C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#     compile options: '-Inumpy/core/src/private -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/home/jayant/anaconda3/envs/tardis/include/python3.8 -c'
#     x86_64-conda-linux-gnu-cc: _configtest.c
#     _configtest.c:1:5: warning: conflicting types for built-in function 'exp'; expected 'double(double)' [-Wbuiltin-declaration-mismatch]
#         1 | int exp (void);
#           |     ^~~
#     _configtest.c:1:1: note: 'exp' is declared in header '<math.h>'
#       +++ |+#include <math.h>
#         1 | int exp (void);
#     /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc _configtest.o -o _configtest
#     /home/jayant/anaconda3/envs/tardis/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/bin/ld: _configtest.o: in function `main':
#     _configtest.c:(.text.startup.main+0x6): undefined reference to `exp'
#     collect2: error: ld returned 1 exit status
#     /home/jayant/anaconda3/envs/tardis/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/bin/ld: _configtest.o: in function `main':
#     _configtest.c:(.text.startup.main+0x6): undefined reference to `exp'
#     collect2: error: ld returned 1 exit status
#     failure.
#     removing: _configtest.c _configtest.o _configtest.o.d
#     C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#     compile options: '-Inumpy/core/src/private -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/home/jayant/anaconda3/envs/tardis/include/python3.8 -c'
#     x86_64-conda-linux-gnu-cc: _configtest.c
#     _configtest.c:1:5: warning: conflicting types for built-in function 'exp'; expected 'double(double)' [-Wbuiltin-declaration-mismatch]
#         1 | int exp (void);
#           |     ^~~
#     _configtest.c:1:1: note: 'exp' is declared in header '<math.h>'
#       +++ |+#include <math.h>
#         1 | int exp (void);
#     /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc _configtest.o -lm -o _configtest
#     success!
#     removing: _configtest.c _configtest.o _configtest.o.d _configtest
#       adding 'build/src.linux-x86_64-3.8/numpy/core/src/npymath' to include_dirs.
#     None - nothing done with h_files = ['build/src.linux-x86_64-3.8/numpy/core/src/npymath/npy_math_internal.h']
#     building library "npysort" sources
#       adding 'build/src.linux-x86_64-3.8/numpy/core/src/private' to include_dirs.
#     None - nothing done with h_files = ['build/src.linux-x86_64-3.8/numpy/core/src/private/npy_partition.h', 'build/src.linux-x86_64-3.8/numpy/core/src/private/npy_binsearch.h']
#     building extension "numpy.core._dummy" sources
#       adding 'build/src.linux-x86_64-3.8/numpy/core/include/numpy/config.h' to sources.
#       adding 'build/src.linux-x86_64-3.8/numpy/core/include/numpy/_numpyconfig.h' to sources.
#     executing numpy/core/code_generators/generate_numpy_api.py
#       adding 'build/src.linux-x86_64-3.8/numpy/core/include/numpy/__multiarray_api.h' to sources.
#     numpy.core - nothing done with h_files = ['build/src.linux-x86_64-3.8/numpy/core/include/numpy/config.h', 'build/src.linux-x86_64-3.8/numpy/core/include/numpy/_numpyconfig.h', 'build/src.linux-x86_64-3.8/numpy/core/include/numpy/__multiarray_api.h']
#     building extension "numpy.core.multiarray" sources
#       adding 'build/src.linux-x86_64-3.8/numpy/core/include/numpy/config.h' to sources.
#       adding 'build/src.linux-x86_64-3.8/numpy/core/include/numpy/_numpyconfig.h' to sources.
#     executing numpy/core/code_generators/generate_numpy_api.py
#       adding 'build/src.linux-x86_64-3.8/numpy/core/include/numpy/__multiarray_api.h' to sources.
#       adding 'build/src.linux-x86_64-3.8/numpy/core/src/private' to include_dirs.
#     numpy.core - nothing done with h_files = ['build/src.linux-x86_64-3.8/numpy/core/src/private/templ_common.h', 'build/src.linux-x86_64-3.8/numpy/core/include/numpy/config.h', 'build/src.linux-x86_64-3.8/numpy/core/include/numpy/_numpyconfig.h', 'build/src.linux-x86_64-3.8/numpy/core/include/numpy/__multiarray_api.h']
#     building extension "numpy.core.umath" sources
#       adding 'build/src.linux-x86_64-3.8/numpy/core/include/numpy/config.h' to sources.
#       adding 'build/src.linux-x86_64-3.8/numpy/core/include/numpy/_numpyconfig.h' to sources.
#     executing numpy/core/code_generators/generate_ufunc_api.py
#       adding 'build/src.linux-x86_64-3.8/numpy/core/include/numpy/__ufunc_api.h' to sources.
#       adding 'build/src.linux-x86_64-3.8/numpy/core/src/umath' to include_dirs.
#     numpy.core - nothing done with h_files = ['build/src.linux-x86_64-3.8/numpy/core/src/umath/funcs.inc', 'build/src.linux-x86_64-3.8/numpy/core/src/umath/simd.inc', 'build/src.linux-x86_64-3.8/numpy/core/src/umath/loops.h', 'build/src.linux-x86_64-3.8/numpy/core/include/numpy/config.h', 'build/src.linux-x86_64-3.8/numpy/core/include/numpy/_numpyconfig.h', 'build/src.linux-x86_64-3.8/numpy/core/include/numpy/__ufunc_api.h']
#     building extension "numpy.core._umath_tests" sources
#     building extension "numpy.core._rational_tests" sources
#     building extension "numpy.core._struct_ufunc_tests" sources
#     building extension "numpy.core._multiarray_tests" sources
#     building extension "numpy.core._operand_flag_tests" sources
#     building extension "numpy.fft.fftpack_lite" sources
#     building extension "numpy.linalg.lapack_lite" sources
#       adding 'numpy/linalg/lapack_lite/python_xerbla.c' to sources.
#     building extension "numpy.linalg._umath_linalg" sources
#       adding 'numpy/linalg/lapack_lite/python_xerbla.c' to sources.
#     building extension "numpy.random.mtrand" sources
#     building data_files sources
#     build_src: building npy-pkg config files
#     running build_py
#     copying numpy/version.py -> build/lib.linux-x86_64-3.8/numpy
#     copying build/src.linux-x86_64-3.8/numpy/__config__.py -> build/lib.linux-x86_64-3.8/numpy
#     copying build/src.linux-x86_64-3.8/numpy/distutils/__config__.py -> build/lib.linux-x86_64-3.8/numpy/distutils
#     running build_clib
#     customize UnixCCompiler
#     C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#     creating /tmp/tmpggybr30p/tmp
#     creating /tmp/tmpggybr30p/tmp/tmpggybr30p
#     compile options: '-MMD -MF /tmp/tmpggybr30p/file.c.d -c'
#     x86_64-conda-linux-gnu-cc: /tmp/tmpggybr30p/file.c
#     customize UnixCCompiler using build_clib
#     running build_ext
#     customize UnixCCompiler
#     C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#     creating /tmp/tmpotscnuy5/tmp
#     creating /tmp/tmpotscnuy5/tmp/tmpotscnuy5
#     compile options: '-MMD -MF /tmp/tmpotscnuy5/file.c.d -c'
#     x86_64-conda-linux-gnu-cc: /tmp/tmpotscnuy5/file.c
#     customize UnixCCompiler using build_ext
#     get_default_fcompiler: matching types: '['gnu95', 'intel', 'lahey', 'pg', 'absoft', 'nag', 'vast', 'compaq', 'intele', 'intelem', 'gnu', 'g95', 'pathf95', 'nagfor']'
#     customize Gnu95FCompiler
#     customize Gnu95FCompiler
#     customize Gnu95FCompiler using build_ext
#     building 'numpy.linalg.lapack_lite' extension
#     compiling C sources
#     C compiler: /home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC
#
#     compile options: '-DNO_ATLAS_INFO=1 -I/usr/local/include -I/usr/include -I/home/jayant/anaconda3/envs/tardis/include -Inumpy/core/include -Ibuild/src.linux-x86_64-3.8/numpy/core/include/numpy -Inumpy/core/src/private -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/home/jayant/anaconda3/envs/tardis/include/python3.8 -Ibuild/src.linux-x86_64-3.8/numpy/core/src/private -Ibuild/src.linux-x86_64-3.8/numpy/core/src/npymath -Ibuild/src.linux-x86_64-3.8/numpy/core/src/private -Ibuild/src.linux-x86_64-3.8/numpy/core/src/npymath -Ibuild/src.linux-x86_64-3.8/numpy/core/src/private -Ibuild/src.linux-x86_64-3.8/numpy/core/src/npymath -c'
#     x86_64-conda-linux-gnu-cc: numpy/linalg/lapack_litemodule.c
#     x86_64-conda-linux-gnu-cc: numpy/linalg/lapack_lite/python_xerbla.c
#     In file included from /home/jayant/anaconda3/envs/tardis/include/python3.8/Python.h:11,
#                      from numpy/linalg/lapack_litemodule.c:7:
#     /usr/include/limits.h:26:10: fatal error: bits/libc-header-start.h: No such file or directory
#        26 | #include <bits/libc-header-start.h>
#           |          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#     compilation terminated.
#     In file included from /home/jayant/anaconda3/envs/tardis/include/python3.8/Python.h:11,
#                      from numpy/linalg/lapack_litemodule.c:7:
#     /usr/include/limits.h:26:10: fatal error: bits/libc-header-start.h: No such file or directory
#        26 | #include <bits/libc-header-start.h>
#           |          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#     compilation terminated.
#     In file included from /home/jayant/anaconda3/envs/tardis/include/python3.8/Python.h:11,
#                      from numpy/linalg/lapack_lite/python_xerbla.c:1:
#     /usr/include/limits.h:26:10: fatal error: bits/libc-header-start.h: No such file or directory
#        26 | #include <bits/libc-header-start.h>
#           |          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#     compilation terminated.
#     In file included from /home/jayant/anaconda3/envs/tardis/include/python3.8/Python.h:11,
#                      from numpy/linalg/lapack_lite/python_xerbla.c:1:
#     /usr/include/limits.h:26:10: fatal error: bits/libc-header-start.h: No such file or directory
#        26 | #include <bits/libc-header-start.h>
#           |          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#     compilation terminated.
#     error: Command "/home/jayant/anaconda3/envs/tardis/bin/x86_64-conda-linux-gnu-cc -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -Wstrict-prototypes -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -pipe -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /home/jayant/anaconda3/envs/tardis/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /home/jayant/anaconda3/envs/tardis/include -fPIC -DNO_ATLAS_INFO=1 -I/usr/local/include -I/usr/include -I/home/jayant/anaconda3/envs/tardis/include -Inumpy/core/include -Ibuild/src.linux-x86_64-3.8/numpy/core/include/numpy -Inumpy/core/src/private -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/home/jayant/anaconda3/envs/tardis/include/python3.8 -Ibuild/src.linux-x86_64-3.8/numpy/core/src/private -Ibuild/src.linux-x86_64-3.8/numpy/core/src/npymath -Ibuild/src.linux-x86_64-3.8/numpy/core/src/private -Ibuild/src.linux-x86_64-3.8/numpy/core/src/npymath -Ibuild/src.linux-x86_64-3.8/numpy/core/src/private -Ibuild/src.linux-x86_64-3.8/numpy/core/src/npymath -c numpy/linalg/lapack_litemodule.c -o build/temp.linux-x86_64-3.8/numpy/linalg/lapack_litemodule.o -MMD -MF build/temp.linux-x86_64-3.8/numpy/linalg/lapack_litemodule.o.d" failed with exit status 1
#     ----------------------------------------
#   Rolling back uninstall of numpy
#   Moving to /home/jayant/anaconda3/envs/tardis/bin/f2py
#    from /tmp/pip-uninstall-hyiv77rm/f2py
#   Moving to /home/jayant/anaconda3/envs/tardis/bin/f2py3
#    from /tmp/pip-uninstall-hyiv77rm/f2py3
#   Moving to /home/jayant/anaconda3/envs/tardis/bin/f2py3.8
#    from /tmp/pip-uninstall-hyiv77rm/f2py3.8
#   Moving to /home/jayant/anaconda3/envs/tardis/lib/python3.8/site-packages/numpy-1.19.5.dist-info/
#    from /home/jayant/anaconda3/envs/tardis/lib/python3.8/site-packages/~umpy-1.19.5.dist-info
#   Moving to /home/jayant/anaconda3/envs/tardis/lib/python3.8/site-packages/numpy/
#    from /home/jayant/anaconda3/envs/tardis/lib/python3.8/site-packages/~umpy
# ERROR: Command errored out with exit status 1: /home/jayant/anaconda3/envs/tardis/bin/python3.8 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-qnwwzi3d/numpy_3810a2a7a2e1465b9ca7891a3217754a/setup.py'"'"'; __file__='"'"'/tmp/pip-install-qnwwzi3d/numpy_3810a2a7a2e1465b9ca7891a3217754a/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-b_uhsn2k/install-record.txt --single-version-externally-managed --compile --install-headers /home/jayant/anaconda3/envs/tardis/include/python3.8/numpy Check the logs for full command output.

# %%
# Download the atomic data

# !wget "https://github.com/tardis-sn/tardis-refdata/raw/master/atom_data/kurucz_cd23_chianti_H_He.h5"

# %%
#Read in atomic data using pandas

import pandas as pd

data = pd.HDFStore('kurucz_cd23_chianti_H_He.h5')

# %%
# Different datasets are stored in the h5 file

set(data)
# Out:
# {'/atom_data',
#  '/collision_data',
#  '/collision_data_temperatures',
#  '/ionization_data',
#  '/levels',
#  '/lines',
#  '/macro_atom_data',
#  '/macro_atom_references',
#  '/zeta_data'}

# %% [markdown]
# ---
#
# #### When a star ends its life in a supernova explosion it releases a huge amount of material we call **ejecta**.
#
# <img src="https://en.es-static.us/upl/2015/01/supernova-artist-e1493935487104.jpg" width="500" height="500">
#
#
# #### The ejecta is made up of lots of different elements. As light travels through the ejecta it gets absorbed and emitted many times by different atoms before leaving the ejecta and traveling through space to reach our telescopes.

# %% [markdown]
# ---
# #### Supernova light then goes through a prism-like instrument that spreads out the light into different colors or wavelengths. The spread out light is called a **spectrum**.
#
#
# ![image.png](data:image/png;base64,...)
#
#
# #### TARDIS is able to create a simulated supernova spectrum that astronomers use to study the physics of exploding stars.
#
# #### The atomic data we just downloaded is an integral part of the TARDIS code. It is used everytime a user tries to make simulated supernova spectrum.

# %%
data['atom_data']
# Out:
#               symbol        name       mass
# atomic_number
# 1                  H    Hydrogen   1.007975
# 2                 He      Helium   4.002602
# 3                 Li     Lithium   6.967500
# 4                 Be   Beryllium   9.012183
# 5                  B       Boron  10.813500
# 6                  C      Carbon  12.010600
# 7                  N    Nitrogen  14.006855
# 8                  O      Oxygen  15.999400
# 9                  F    Fluorine  18.998403
# 10                Ne        Neon  20.179700
# 11                Na      Sodium  22.989769
# 12                Mg   Magnesium  24.305500
# 13                Al   Aluminium  26.981538
# 14                Si     Silicon  28.085000
# 15                 P  Phosphorus  30.973762
# 16                 S      Sulfur  32.067500
# 17                Cl    Chlorine  35.451500
# 18                Ar       Argon  39.948000
# 19                 K   Potassium  39.098300
# 20                Ca     Calcium  40.078000
# 21                Sc    Scandium  44.955908
# 22                Ti    Titanium  47.867000
# 23                 V    Vanadium  50.941500
# 24                Cr    Chromium  51.996100
# 25                Mn   Manganese  54.938044
# 26                Fe        Iron  55.845000
# 27                Co      Cobalt  58.933194
# 28                Ni      Nickel  58.693400
# 29                Cu      Copper  63.546000
# 30                Zn        Zinc  65.380000

# %% [markdown]
# ---
#
# # TASK #1
# **Background**
#
# - Iron Group Elements (IGE) are Cr, Mn, Fe, Co, Ni. They are particularly important elements that are found in the ejecta of supernovas.
#
# ***Mission A*: Make a new pandas dataframe with elements that have atomic masses between 51 and 60 (Iron Group Elements)**

# %%
# Let's grab all the elements with masses between 51 and 60 (Iron group elements)

Iron_group_elements = data['atom_data'][(data['atom_data']['mass']>50) & (data['atom_data']['mass']<60)]

# %%
# Print out the new dataframe called Iron_group_elements

Iron_group_elements
# Out:
#               symbol       name       mass
# atomic_number
# 23                 V   Vanadium  50.941500
# 24                Cr   Chromium  51.996100
# 25                Mn  Manganese  54.938044
# 26                Fe       Iron  55.845000
# 27                Co     Cobalt  58.933194
# 28                Ni     Nickel  58.693400

# %% [markdown]
# <details>
#   <summary>Hint!</summary>
#
#
# *   Make conditions to create a series object
# *   ie. data['atom_data']['mass'] > 50
#
#
# </details>

# %% [markdown]
# ***Mission B*: Add a new column called IGE to data['atom_data']** *Optional challenge*
#
# - The IGE(Iron Group Elements) value can either be 1 or True if the element is an IGE , or 0 or False if it is not an IGE.

# %%
df = data['atom_data']

# Add new column called IGE to df 

df['IGE']=(data['atom_data']['mass']>50) & (data['atom_data']['mass']<60)

# %%
# Print out the new dataframe with IGE column

df
# Out:
#               symbol        name       mass    IGE
# atomic_number
# 1                  H    Hydrogen   1.007975  False
# 2                 He      Helium   4.002602  False
# 3                 Li     Lithium   6.967500  False
# 4                 Be   Beryllium   9.012183  False
# 5                  B       Boron  10.813500  False
# 6                  C      Carbon  12.010600  False
# 7                  N    Nitrogen  14.006855  False
# 8                  O      Oxygen  15.999400  False
# 9                  F    Fluorine  18.998403  False
# 10                Ne        Neon  20.179700  False
# 11                Na      Sodium  22.989769  False
# 12                Mg   Magnesium  24.305500  False
# 13                Al   Aluminium  26.981538  False
# 14                Si     Silicon  28.085000  False
# 15                 P  Phosphorus  30.973762  False
# 16                 S      Sulfur  32.067500  False
# 17                Cl    Chlorine  35.451500  False
# 18                Ar       Argon  39.948000  False
# 19                 K   Potassium  39.098300  False
# 20                Ca     Calcium  40.078000  False
# 21                Sc    Scandium  44.955908  False
# 22                Ti    Titanium  47.867000  False
# 23                 V    Vanadium  50.941500   True
# 24                Cr    Chromium  51.996100   True
# 25                Mn   Manganese  54.938044   True
# 26                Fe        Iron  55.845000   True
# 27                Co      Cobalt  58.933194   True
# 28                Ni      Nickel  58.693400   True
# 29                Cu      Copper  63.546000  False
# 30                Zn        Zinc  65.380000  False

# %% [markdown]
# ---
#
# # TASK #2
#
# **Background**
#  - Radioactive Nickel-56 is produced in large quantities in supernovas. A lot of the supernova light (photons) that we see comes from the decay of nickel-56 to cobalt-56
#
#  - Ni$^{56}$ $\rightarrow$  Co$^{56}$ + $\gamma$ (photons) + $\nu$ (neutrinos)
#
#  - Total energy emitted via $\gamma$ photons = 1.75 MeV (Mega electron volts)
#  - Total energy emitted via $\nu$ neutrinos = 0.41 MeV (Mega electron volts)
#
# **Mission: Make a function that takes in the number of nickel-56 and outputs the energy released by photons and neutrinos**

# %%
def Ni56toCo56 (Ni56):
    # Function that inputs number of Ni56 atoms and outputs energy of photons and neutrinos
    E_photons= format(Ni56 * 1.75, "5.3E")
    E_neutrinos= format(Ni56 * 0.41, "5.3E")
  # Optional:
  # Try to return E_photons and E_neutrinos in scientific notation with 4 significant figures (ie. 1750000.0 --> 1.750e6)
    return E_photons, E_neutrinos

# %%
# Test your function here

# Number of Nickel-56 atoms 
Ni56_number = 10**6
E_photons, E_neutrinos = Ni56toCo56(Ni56_number)

# %%
# Results 
print('E_photons = ', E_photons, 'MeV')
print('E_neutrinos = ', E_neutrinos, 'MeV')
# Out:
# E_photons =  1.750E+06 MeV
# E_neutrinos =  4.100E+05 MeV

# %% [markdown]
# ---
#
# # TASK #3
#
# **Background**
#  - Supernovas can release up to 1.2  solar masses of Nickel-56 (meaning they can release more mass than is in our Sun!)
#
#  - We will assume that all of the Nickel-56 decays and releases energy
#
# **Mission: How much TOTAL energy is released by Ni56 in a supernova?**

# %% [markdown]
# Feel free to solve this problem using whatever method you would like

# %%
# If you want to use the function from Task 2, you will need to find out how many Nickel 56 atoms are in 1.2 solar masses
Ni56_number= (2.387e+33/56)*6.022e+23

# %% [markdown]
# <details>
#   <summary>Hint!</summary>
#
# *   Create a function that will convert solar_mass to Ni56_number
# *   1 solar mass = 1.198*10^(57) Daltons (atomic mass units)
# *   There are ~ 56 atomic mass units in Nickel-56
#
#
# </details>

# %%
# Calculate total energy released (Assuming you used the Ni56toCo56 function from Task 2 )
E_photons, E_neutrinos = Ni56toCo56(Ni56_number)
E_total = format(float(E_photons) + float(E_neutrinos),"3.1e")
E_total
# Out:
# '5.5e+55'

# %%
# Print results

print('Energy release by Ni56 in a supernova = ', E_total, ' MeV')
print('    ')
print('For comparison:') 
print('Energy released by the most powerful nuclear weapon ever detonated is 1.3e30 MeV')
# Out:
# Energy release by Ni56 in a supernova =  5.5e+55  MeV
#
# For comparison:
# Energy released by the most powerful nuclear weapon ever detonated is 1.3e30 MeV

# %% [markdown]
# ### Finished!
# ## You figured out that supernovas are some of the most powerful explosions in the Universe!
